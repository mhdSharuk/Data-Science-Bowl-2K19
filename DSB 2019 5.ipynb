# %% [markdown]
# **Notes**
#
# **1) Description of the all the columns**
#
#
#
#
#
# *   **event_id** - Randomly generated unique identifier for the event type. Maps to event_id column in specs table.
# *   **game_session** - Randomly generated unique identifier grouping events within a single game or video play session.
# *   **timestamp** - Client-generated datetime
# *   **event_data** - Semi-structured JSON formatted string containing the events parameters. Default fields are: event_count, event_code, and game_time; otherwise fields are determined by the event type.
# *   **installation_id** - Randomly generated unique identifier grouping game sessions within a single installed application instance.
# *   **event_count** - Incremental counter of events within a game session (offset at 1). Extracted from event_data.
# *   **event_code** - Identifier of the event 'class'. Unique per game, but may be duplicated across games. E.g. event code '2000' always identifies the 'Start Game' event for all games. Extracted from event_data.
# *   **game_time** - Time in milliseconds since the start of the game session. Extracted from event_data.
# *   **title** - Title of the game or video.
# *   **type** - Media type of the game or video. Possible values are: 'Game', 'Assessment', 'Activity', 'Clip'.
# *   **world** - The section of the application the game or video belongs to. Helpful to identify the educational curriculum goals of the media. Possible values are: 'NONE' (at the app's start screen), TREETOPCITY' (Length/Height), 'MAGMAPEAK' (Capacity/Displacement), 'CRYSTALCAVES' (Weight).
#
#
#
#
#
#
# **2) Groupby data to get the number of attempts each installation_id played**
#
#
# *   train_data.groupby(['game_session','installation_id'],as_index =False)['title'].agg({'value_counts'}).rename(columns={'value_counts':'Total_no'}).head()
#
# *   test_data.groupby(['game_session','installation_id'])['title'].agg({'value_counts'}).rename(columns={'value_counts':'Total_no'}).index.get_level_values(3)
#
#
# **3) Event Codes Meaning**
#
# *   2000 : Start of the game
# *   3010 : Voice description of what to do in the game
# *   3110 : Starting of game with the voice description in the background
# *   4070 : Player starting to play the game
#
#
# **4) Data Analysis**
# * All Event Id has the same value for a particular game title event though they have different installation id
# * All Event Code have same value for a particular Event Id
#
# **5) Approach to solutions**
# * first

# %% [markdown]
# **Importing the modules**

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns', None)
import datetime
from catboost import CatBoostClassifier
from time import time
from tqdm import tqdm_notebook as tqdm
import os
import random
import json
import pprint
import gc
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold,GroupKFold
from sklearn.metrics import confusion_matrix

# %% [markdown]
# **Making Event Determenistic**

# %%
def seed_everything(seed=0):
  random.seed(seed)
  os.environ['PYTHONHASHSEED'] = str(seed)
  np.random.seed(seed)

# %%
seed_everything(70)

# %% [markdown]
# **The Competition Eval Metric : Quadratic Weight Kappa**

# %%
def quadratic_weight_kappa(actual, prediction,n=4,hist_range=(0,3)):
  O = confusion_matrix(actual,prediction)
  O = np.divide(O,np.sum(O))

  W = np.zeros((n,n))
  for i in range(n):
    for j in range(n):
      W[i][j] = ((i-j)**2)/((n-1)**2)

  actual_histogram = np.histogram(actual,bins=n,range=hist_range)[0]
  prediction_histogram = np.histogram(prediction,bins=n,range=hist_range)[0]

  E = np.outer(actual_histogram,prediction_histogram)
  E = np.divide(E,np.sum(E))

  num = np.sum(np.multiply(W,O))
  density = np.sum(np.multiply(W,E))

  return 1 - np.divide(num,density)

# %%
def pretty_json(data):
    return pprint.pprint(json.loads(data))

# %%
def read_file():
    train = pd.read_csv('/kaggle/input/data-science-bowl-2019/train.csv')
    train_labels = pd.read_csv('/kaggle/input/data-science-bowl-2019/train_labels.csv')
    specs = pd.read_csv('/kaggle/input/data-science-bowl-2019/specs.csv')
    test = pd.read_csv('/kaggle/input/data-science-bowl-2019/test.csv')
    submission = pd.read_csv('/kaggle/input/data-science-bowl-2019/sample_submission.csv')
    
    return train,train_labels,specs,test,submission

# %% [markdown]
# **Reading the files**

# %%
train,train_labels,specs,test,submission = read_file()

# %% [markdown]
# **Filtering out the train set having installation id that have atleast one assessment done**

# %%
train_install_id = list(train['installation_id'].unique())

# %%
assessment_id = list(train[train['type'] == 'Assessment']['installation_id'].unique())
train = train.loc[train['installation_id'].isin(assessment_id)]

# %%
train.shape
# Out:
# (8294138, 11)

# %%
list_of_user_activities = list(set(train['title'].value_counts().index).union(set(test['title'].value_counts().index)))
activities_map = dict(zip(list_of_user_activities, np.arange(len(list_of_user_activities))))

train['title'] = train['title'].map(activities_map)
test['title'] = test['title'].map(activities_map)
train_labels['title'] = train_labels['title'].map(activities_map)

# %%
ids = list(train_labels['installation_id'].unique())
train = train.loc[train['installation_id'].isin(ids)]

# %%
session = train_labels['game_session'].values
acc_group = train_labels['accuracy_group'].values
match_data = dict(zip(session,acc_group))

# %%
win_code = dict(zip(activities_map.values(), (4100*np.ones(len(activities_map))).astype('int')))
win_code[activities_map['Bird Measurer (Assessment)']] = 4110

# %%
train['timestamp'] = pd.to_datetime(train['timestamp'])
test['timestamp'] = pd.to_datetime(test['timestamp'])

# %%
train = train.reset_index(drop=False)
train.drop(columns = ['index'],axis = 1, inplace = True)

# %%
train = train[train['type'] == 'Assessment']

# %%
train = train[(train['type'] == 'Assessment') & ((train['event_code'] == 4100) | ((train['event_code'] == 4110) & (train['title'] == 'Bird Measurer (Assessment)')))]
train.shape
# Out:
# (43901, 11)

# %%
train_labels[train_labels['game_session'] == '3beae5a17e0b26f6']
# Out:
#         game_session installation_id                       title  num_correct  \
# 28  3beae5a17e0b26f6        003372b0  Cart Balancer (Assessment)            1
#
#     num_incorrect  accuracy  accuracy_group
# 28              0       1.0               3

# %%
train.head(100)
# Out:
#         game_session installation_id  game_time                         title  \
# 0   901acc108f55a5a1        0006a69f      31011  Mushroom Sorter (Assessment)
# 1   77b8ee947eb84b4e        0006a69f      35771    Bird Measurer (Assessment)
# 2   77b8ee947eb84b4e        0006a69f      42805    Bird Measurer (Assessment)
# 3   77b8ee947eb84b4e        0006a69f      47388    Bird Measurer (Assessment)
# 4   77b8ee947eb84b4e        0006a69f      50605    Bird Measurer (Assessment)
# 5   77b8ee947eb84b4e        0006a69f      54822    Bird Measurer (Assessment)
# 6   77b8ee947eb84b4e        0006a69f      58280    Bird Measurer (Assessment)
# 7   77b8ee947eb84b4e        0006a69f      62256    Bird Measurer (Assessment)
# 8   77b8ee947eb84b4e        0006a69f      67164    Bird Measurer (Assessment)
# 9   77b8ee947eb84b4e        0006a69f      73056    Bird Measurer (Assessment)
# 91  28113cd58d865372        003372b0      47423    Bird Measurer (Assessment)
# 92  3beae5a17e0b26f6        003372b0      22643    Cart Balancer (Assessment)
# 93  0adc585fb4f48458        003372b0      20734    Cart Balancer (Assessment)
# 94  4649b29840d5b0f1        003372b0      25639     Chest Sorter (Assessment)
# 95  4649b29840d5b0f1        003372b0      40189     Chest Sorter (Assessment)
# 96  4649b29840d5b0f1        003372b0      50589     Chest Sorter (Assessment)
# 97  4649b29840d5b0f1        003372b0      64373     Chest Sorter (Assessment)
# 98  272cc78535e9add1        003372b0      19657  Cauldron Filler (Assessment)
# 99  3a50778205e34531        004c2091      11353  Cauldron Filler (Assessment)
#
#           type         world  num_correct  num_incorrect  total_attempt  \
# 0   Assessment   TREETOPCITY            1              0              1
# 1   Assessment   TREETOPCITY            0             11             11
# 2   Assessment   TREETOPCITY            0             11             11
# 3   Assessment   TREETOPCITY            0             11             11
# 4   Assessment   TREETOPCITY            0             11             11
# 5   Assessment   TREETOPCITY            0             11             11
# 6   Assessment   TREETOPCITY            0             11             11
# 7   Assessment   TREETOPCITY            0             11             11
# 8   Assessment   TREETOPCITY            0             11             11
# 9   Assessment   TREETOPCITY            0             11             11
# 10  Assessment   TREETOPCITY            0             11             11
# 11  Assessment   TREETOPCITY            0             11             11
# 12  Assessment   TREETOPCITY            1              0              1
# 13  Assessment   TREETOPCITY            1              1              2
# 14  Assessment   TREETOPCITY            1              1              2
# 15  Assessment   TREETOPCITY            2              0              2
# 16  Assessment   TREETOPCITY            2              0              2
# 17  Assessment     MAGMAPEAK            1              0              1
# 18  Assessment   TREETOPCITY            0              4              4
# 19  Assessment   TREETOPCITY            0              4              4
# 20  Assessment   TREETOPCITY            0              4              4
# 21  Assessment   TREETOPCITY            0              4              4
# 22  Assessment   TREETOPCITY            1              2              3
# 23  Assessment   TREETOPCITY            1              2              3
# 24  Assessment   TREETOPCITY            1              2              3
# 25  Assessment   TREETOPCITY            2              0              2
# 26  Assessment   TREETOPCITY            2              0              2
# 27  Assessment   TREETOPCITY            1              1              2
# 28  Assessment   TREETOPCITY            1              1              2
# 29  Assessment   TREETOPCITY            1              0              1
# 30  Assessment   TREETOPCITY            0              5              5
# 31  Assessment   TREETOPCITY            0              5              5
# 32  Assessment   TREETOPCITY            0              5              5
# 33  Assessment   TREETOPCITY            0              5              5
# 34  Assessment   TREETOPCITY            0              5              5
# 35  Assessment  CRYSTALCAVES            1              0              1
# 36  Assessment  CRYSTALCAVES            0              1              1
# 37  Assessment   TREETOPCITY            0              2              2
# 38  Assessment   TREETOPCITY            0              2              2
# 39  Assessment  CRYSTALCAVES            0             11             11
# 40  Assessment  CRYSTALCAVES            0             11             11
# 41  Assessment  CRYSTALCAVES            0             11             11
# 42  Assessment  CRYSTALCAVES            0             11             11
# 43  Assessment  CRYSTALCAVES            0             11             11
# 44  Assessment  CRYSTALCAVES            0             11             11
# 45  Assessment  CRYSTALCAVES            0             11             11
# 46  Assessment  CRYSTALCAVES            0             11             11
# 47  Assessment  CRYSTALCAVES            0             11             11
# 48  Assessment  CRYSTALCAVES            0             11             11
# 49  Assessment  CRYSTALCAVES            0             11             11
# 50  Assessment  CRYSTALCAVES            0              5              5
# 51  Assessment  CRYSTALCAVES            0              5              5
# 52  Assessment  CRYSTALCAVES            0              5              5
# 53  Assessment  CRYSTALCAVES            0              5              5
# 54  Assessment  CRYSTALCAVES            0              5              5
# 55  Assessment   TREETOPCITY            1              1              2
# 56  Assessment   TREETOPCITY            1              1              2
# 57  Assessment   TREETOPCITY            2             10             12
# 58  Assessment   TREETOPCITY            2             10             12
# 59  Assessment   TREETOPCITY            2             10             12
# 60  Assessment   TREETOPCITY            2             10             12
# 61  Assessment   TREETOPCITY            2             10             12
# 62  Assessment   TREETOPCITY            2             10             12
# 63  Assessment   TREETOPCITY            2             10             12
# 64  Assessment   TREETOPCITY            2             10             12
# 65  Assessment   TREETOPCITY            2             10             12
# 66  Assessment   TREETOPCITY            2             10             12
# 67  Assessment   TREETOPCITY            2             10             12
# 68  Assessment   TREETOPCITY            2             10             12
# 69  Assessment  CRYSTALCAVES            1              0              1
# 70  Assessment  CRYSTALCAVES            0              7              7
# 71  Assessment  CRYSTALCAVES            0              7              7
# 72  Assessment  CRYSTALCAVES            0              7              7
# 73  Assessment  CRYSTALCAVES            0              7              7
# 74  Assessment  CRYSTALCAVES            0              7              7
# 75  Assessment  CRYSTALCAVES            0              7              7
# 76  Assessment  CRYSTALCAVES            0              7              7
# 77  Assessment     MAGMAPEAK            1              0              1
# 78  Assessment   TREETOPCITY            1              0              1
# 79  Assessment   TREETOPCITY            2              1              3
# 80  Assessment   TREETOPCITY            2              1              3
# 81  Assessment   TREETOPCITY            2              1              3
# 82  Assessment   TREETOPCITY            2              4              6
# 83  Assessment   TREETOPCITY            2              4              6
# 84  Assessment   TREETOPCITY            2              4              6
# 85  Assessment   TREETOPCITY            2              4              6
# 86  Assessment   TREETOPCITY            2              4              6
# 87  Assessment   TREETOPCITY            2              4              6
# 88  Assessment   TREETOPCITY            1              0              1
# 89  Assessment   TREETOPCITY            2              1              3
# 90  Assessment   TREETOPCITY            2              1              3
# 91  Assessment   TREETOPCITY            2              1              3
# 92  Assessment  CRYSTALCAVES            1              0              1
# 93  Assessment  CRYSTALCAVES            1              0              1
# 94  Assessment  CRYSTALCAVES            0              4              4
# 95  Assessment  CRYSTALCAVES            0              4              4
# 96  Assessment  CRYSTALCAVES            0              4              4
# 97  Assessment  CRYSTALCAVES            0              4              4
# 98  Assessment     MAGMAPEAK            1              0              1
# 99  Assessment     MAGMAPEAK            1              0              1
#
#     accuracy  accuracy_group
# 0   1.000000             3.0
# 1   0.000000             0.0
# 2   0.000000             0.0
# 3   0.000000             0.0
# 4   0.000000             0.0
# 5   0.000000             0.0
# 6   0.000000             0.0
# 7   0.000000             0.0
# 8   0.000000             0.0
# 9   0.000000             0.0
# 10  0.000000             0.0
# 11  0.000000             0.0
# 12  1.000000             3.0
# 13  0.500000             2.0
# 14  0.500000             2.0
# 15  1.000000             3.0
# 16  1.000000             3.0
# 17  1.000000             3.0
# 18  0.000000             0.0
# 19  0.000000             0.0
# 20  0.000000             0.0
# 21  0.000000             0.0
# 22  0.333333             1.0
# 23  0.333333             1.0
# 24  0.333333             1.0
# 25  1.000000             3.0
# 26  1.000000             3.0
# 27  0.500000             2.0
# 28  0.500000             2.0
# 29  1.000000             3.0
# 30  0.000000             0.0
# 31  0.000000             0.0
# 32  0.000000             0.0
# 33  0.000000             0.0
# 34  0.000000             0.0
# 35  1.000000             3.0
# 36  0.000000             0.0
# 37  0.000000             0.0
# 38  0.000000             0.0
# 39  0.000000             0.0
# 40  0.000000             0.0
# 41  0.000000             0.0
# 42  0.000000             0.0
# 43  0.000000             0.0
# 44  0.000000             0.0
# 45  0.000000             0.0
# 46  0.000000             0.0
# 47  0.000000             0.0
# 48  0.000000             0.0
# 49  0.000000             0.0
# 50  0.000000             0.0
# 51  0.000000             0.0
# 52  0.000000             0.0
# 53  0.000000             0.0
# 54  0.000000             0.0
# 55  0.500000             2.0
# 56  0.500000             2.0
# 57  0.166667             1.0
# 58  0.166667             1.0
# 59  0.166667             1.0
# 60  0.166667             1.0
# 61  0.166667             1.0
# 62  0.166667             1.0
# 63  0.166667             1.0
# 64  0.166667             1.0
# 65  0.166667             1.0
# 66  0.166667             1.0
# 67  0.166667             1.0
# 68  0.166667             1.0
# 69  1.000000             3.0
# 70  0.000000             0.0
# 71  0.000000             0.0
# 72  0.000000             0.0
# 73  0.000000             0.0
# 74  0.000000             0.0
# 75  0.000000             0.0
# 76  0.000000             0.0
# 77  1.000000             3.0
# 78  1.000000             3.0
# 79  0.666667             0.0
# 80  0.666667             0.0
# 81  0.666667             0.0
# 82  0.333333             1.0
# 83  0.333333             1.0
# 84  0.333333             1.0
# 85  0.333333             1.0
# 86  0.333333             1.0
# 87  0.333333             1.0
# 88  1.000000             3.0
# 89  0.666667             0.0
# 90  0.666667             0.0
# 91  0.666667             0.0
# 92  1.000000             3.0
# 93  1.000000             3.0
# 94  0.000000             0.0
# 95  0.000000             0.0
# 96  0.000000             0.0
# 97  0.000000             0.0
# 98  1.000000             3.0
# 99  1.000000             3.0

# %%
session_count = train['game_session'].value_counts().to_dict()
train['assessment_attempt_count'] = train['game_session'].map(session_count)

# %%
train['contains_true_assessment'] = train['event_data'].map(lambda x: True if (x.find('"correct":true')>=0) else False)
#train['contains_true_assessment'] = np.where((((train['event_code'] == 4100) | (train['event_code'] == 4110)) & train['contains_true'] == True),True,None)

# %%
change_value = {
    True : 1,
    False : 0
}
train['contains_true_assessment'] = train['contains_true_assessment'].map(change_value)

# %%
correct_attempt = dict(train.groupby('game_session',sort=False)['contains_true_assessment'].sum())
train['contains_true_assessment_count'] = train['game_session'].map(correct_attempt)

# %%
for c in ['contains_true_assessment']:
    train.pop(c)

# %%
train['accumulated_accuracy'] = np.where((train['contains_true_assessment_count'] == 0),0,(train['contains_true_assessment_count']/train['assessment_attempt_count']))

# %%
train.loc[(train['type'] == 'Assessment'), 'accuracy_group'] = 0
train.loc[(train['accumulated_accuracy'] == 1) & (train['type'] == 'Assessment'), 'accuracy_group'] = 3
train.loc[(train['accumulated_accuracy'] == 0.5) & (train['type'] == 'Assessment'), 'accuracy_group'] = 2
train.loc[(train['accumulated_accuracy'] < 0.5) & (train['accumulated_accuracy'] > 0) & (train['assessment_attempt_count'] > 0) & (train['type'] == 'Assessment'), 'accuracy_group'] = 1

# %%
train.rename(columns = {'contains_true_assessment_count': 'num_correct',
                        'accumulated_accuracy':'accuracy',
                        'assessment_attempt_count': 'total_attempt'},inplace=True)

# %%
train['num_incorrect'] = train['total_attempt'] - train['contains_true_assessment_count']

# %%
for c in ['event_id','timestamp','event_data','event_code','event_count']:
    train.pop(c)

# %%
train.to_csv('./../working/train_data.csv',index=False)

# %%
test[(test['type'] == 'Assessment') & ((test['event_code'] == 4100) | ((test['event_code'] == 4110) & (test['title'] = 'Bird Measurer (Assessment)')))].shape
# Out:
# (1156414, 11)

# %%
test_labels = test[(test['type'] == 'Assessment') & ((test['event_code'] == 4100) | ((test['event_code'] == 4110) & (test['title'] == 'Bird Measurer (Assessment)')))]

# %%
test_labels.head(100)
# Out:
# (4756, 11)

# %%
def make_classifier():
    clf = CatBoostClassifier(
                               loss_function='MultiClass',
                               task_type="CPU",
                               learning_rate=0.01,
                               iterations=100,
                               od_type="Iter",
                               early_stopping_rounds=50,
                               random_seed=2019,
                               colsample_bylevel=0.87,
                               eval_metric='Kappa',
                              )
        
    return clf
oof = np.zeros(len(x))

# %%
params = {
       'loss_function':'MultiClass',
       'task_type':'CPU',
       'learning_rate':0.05,
       'iterations':20,
       'early_stopping_rounds':5,
       'random_seed':89,
       'colsample_bylevel':0.87,
       'eval_metric':'Kappa',
}

# %%
#cat_features = ['Clip','Game','session_title','Activity']

# %%
cat_features = ['Clip']

# %%
oof = np.zeros(len(x))
NFOLDS = 4
folds = KFold(n_splits=NFOLDS)
clf_in_predict = []

for fold, (trn_idx, test_idx) in enumerate(folds.split(x, y)):
    print(f'Training on fold {fold+1}')
    clf = make_classifier()
    clf.fit(x.loc[trn_idx], y.loc[trn_idx], eval_set=(x.loc[test_idx], y.loc[test_idx]),
                          use_best_model=True, verbose=500,cat_features=cat_features)
    
    clf_in_predict = clf.predict(x.loc[test_idx].reshape(len(tets_idx)))
    
    print('-' * 30)
    print('Traning_predict QWK:', quadratic_weight_kappa(y, clf_in_predict))
    print('-' * 30)
    
    oof[test_idx] = clf.predict(x.loc[test_idx]).reshape(len(test_idx))

    
print('-' * 30)
print('OOF QWK:', quadratic_weight_kappa(y, oof))
print('-' * 30)

# %%
# process test set
new_test = []
for ins_id,user_sample in tqdm(test.groupby(['installation_id'], sort=False), total=1000):
    a = get_data(user_sample, test_set=True)
    new_test.append(a)
    
test = pd.DataFrame(new_test)

# %%
test.head()

# %%
preds = clf.predict(test)
del test

# %% [markdown]
# ## Make Submission

# %%
submission['accuracy_group'] = np.round(preds).astype('int')
submission.to_csv('submission.csv', index=None)
submission.head()

# %%
# !rm -rf catboost_info
