# %% [markdown]
# **Notes**
#
# **1) Description of the all the columns**
#
#
#
#
#
# *   **event_id** - Randomly generated unique identifier for the event type. Maps to event_id column in specs table.
# *   **game_session** - Randomly generated unique identifier grouping events within a single game or video play session.
# *   **timestamp** - Client-generated datetime
# *   **event_data** - Semi-structured JSON formatted string containing the events parameters. Default fields are: event_count, event_code, and game_time; otherwise fields are determined by the event type.
# *   **installation_id** - Randomly generated unique identifier grouping game sessions within a single installed application instance.
# *   **event_count** - Incremental counter of events within a game session (offset at 1). Extracted from event_data.
# *   **event_code** - Identifier of the event 'class'. Unique per game, but may be duplicated across games. E.g. event code '2000' always identifies the 'Start Game' event for all games. Extracted from event_data.
# *   **game_time** - Time in milliseconds since the start of the game session. Extracted from event_data.
# *   **title** - Title of the game or video.
# *   **type** - Media type of the game or video. Possible values are: 'Game', 'Assessment', 'Activity', 'Clip'.
# *   **world** - The section of the application the game or video belongs to. Helpful to identify the educational curriculum goals of the media. Possible values are: 'NONE' (at the app's start screen), TREETOPCITY' (Length/Height), 'MAGMAPEAK' (Capacity/Displacement), 'CRYSTALCAVES' (Weight).
#
#
#
#
#
#
# **2) Groupby data to get the number of attempts each installation_id played**
#
#
# *   train_data.groupby(['game_session','installation_id'],as_index =False)['title'].agg({'value_counts'}).rename(columns={'value_counts':'Total_no'}).head()
#
# *   test_data.groupby(['game_session','installation_id'])['title'].agg({'value_counts'}).rename(columns={'value_counts':'Total_no'}).index.get_level_values(3)
#
#
# **3) Event Codes Meaning**
#
# *   2000 : Start of the game
# *   3010 : Voice description of what to do in the game
# *   3110 : Starting of game with the voice description in the background
# *   4070 : Player starting to play the game
#
#
# **4) Data Analysis**
# * All Event Id has the same value for a particular game title event though they have different installation id
# * All Event Code have same value for a particular Event Id
#
# **5) Approach to solutions**
# * first

# %% [markdown]
# **Importing the modules**

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns', None)
import datetime
from catboost import CatBoostClassifier
from time import time
from tqdm import tqdm_notebook as tqdm
import os
import random
import json
import pprint
import gc
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold,GroupKFold
from sklearn.metrics import confusion_matrix

# %% [markdown]
# **Making Event Determenistic**

# %%
def seed_everything(seed=0):
  random.seed(seed)
  os.environ['PYTHONHASHSEED'] = str(seed)
  np.random.seed(seed)

# %%
seed_everything(70)

# %% [markdown]
# **The Competition Eval Metric : Quadratic Weight Kappa**

# %%
def quadratic_weight_kappa(actual, prediction,n=4,hist_range=(0,3)):
  O = confusion_matrix(actual,prediction)
  O = np.divide(O,np.sum(O))

  W = np.zeros((n,n))
  for i in range(n):
    for j in range(n):
      W[i][j] = ((i-j)**2)/((n-1)**2)

  actual_histogram = np.histogram(actual,bins=n,range=hist_range)[0]
  prediction_histogram = np.histogram(prediction,bins=n,range=hist_range)[0]

  E = np.outer(actual_histogram,prediction_histogram)
  E = np.divide(E,np.sum(E))

  num = np.sum(np.multiply(W,O))
  density = np.sum(np.multiply(W,E))

  return 1 - np.divide(num,density)

# %%
def pretty_json(data):
    return pprint.pprint(json.loads(data))

# %%
def read_file():
    train = pd.read_csv('/kaggle/input/data-science-bowl-2019/train.csv')
    train_labels = pd.read_csv('/kaggle/input/data-science-bowl-2019/train_labels.csv')
    specs = pd.read_csv('/kaggle/input/data-science-bowl-2019/specs.csv')
    test = pd.read_csv('/kaggle/input/data-science-bowl-2019/test.csv')
    submission = pd.read_csv('/kaggle/input/data-science-bowl-2019/sample_submission.csv')
    
    return train,train_labels,specs,test,submission

# %% [markdown]
# **Reading the files**

# %%
train,train_labels,specs,test,submission = read_file()

# %% [markdown]
# **Filtering out the train set having installation id that have atleast one assessment done**

# %%
train_install_id = list(train['installation_id'].unique())

# %%
assessment_id = list(train[train['type'] == 'Assessment']['installation_id'].unique())
train = train.loc[train['installation_id'].isin(assessment_id)]

# %%
train.shape

# %%
list_of_user_activities = list(set(train['title'].value_counts().index).union(set(test['title'].value_counts().index)))
activities_map = dict(zip(list_of_user_activities, np.arange(len(list_of_user_activities))))

train['title'] = train['title'].map(activities_map)
test['title'] = test['title'].map(activities_map)
train_labels['title'] = train_labels['title'].map(activities_map)

# %%
ids = list(train_labels['installation_id'].unique())
train = train.loc[train['installation_id'].isin(ids)]

# %%
session = train_labels['game_session'].values
acc_group = train_labels['accuracy_group'].values
match_data = dict(zip(session,acc_group))

# %%
win_code = dict(zip(activities_map.values(), (4100*np.ones(len(activities_map))).astype('int')))
win_code[activities_map['Bird Measurer (Assessment)']] = 4110

# %%
train['timestamp'] = pd.to_datetime(train['timestamp'])
test['timestamp'] = pd.to_datetime(test['timestamp'])

# %%
train = train[(train['type'] == 'Assessment') & (((train['event_code'] == 4100) & (train['title'] != 'Bird Measurer (Assessment)')) | ((train['event_code'] == 4110) & (train['title'] == 'Bird Measurer (Assessment)')))]
train.shape

# %%
train = train.reset_index(drop=False)
train.drop(columns = ['index'],axis = 1, inplace = True)

# %%
session_count = train['game_session'].value_counts().to_dict()
train['assessment_attempt_count'] = train['game_session'].map(session_count)

# %%
train['contains_true_assessment'] = train['event_data'].map(lambda x: True if (x.find('"correct":true')>=0) else False)
#train['contains_true_assessment'] = np.where((((train['event_code'] == 4100) | (train['event_code'] == 4110)) & train['contains_true'] == True),True,None)

# %%
change_value = {
    True : 1,
    False : 0
}
train['contains_true_assessment'] = train['contains_true_assessment'].map(change_value)

# %%
correct_attempt = dict(train.groupby('game_session',sort=False)['contains_true_assessment'].sum())
train['contains_true_assessment_count'] = train['game_session'].map(correct_attempt)

# %%
for c in ['contains_true_assessment']:
    train.pop(c)

# %%
train['accumulated_accuracy'] = np.where((train['contains_true_assessment_count'] == 0),0,(train['contains_true_assessment_count']/train['assessment_attempt_count']))

# %%
train.loc[(train['type'] == 'Assessment'), 'accuracy_group'] = 0
train.loc[(train['accumulated_accuracy'] == 1) & (train['type'] == 'Assessment'), 'accuracy_group'] = 3
train.loc[(train['accumulated_accuracy'] == 0.5) & (train['type'] == 'Assessment'), 'accuracy_group'] = 2
train.loc[(train['accumulated_accuracy'] < 0.5) & (train['accumulated_accuracy'] > 0) & (train['assessment_attempt_count'] > 0) & (train['type'] == 'Assessment'), 'accuracy_group'] = 1

# %%
train.rename(columns = {'contains_true_assessment_count': 'num_correct',
                        'accumulated_accuracy':'accuracy',
                        'assessment_attempt_count': 'total_attempt'},inplace=True)

# %%
train['num_incorrect'] = train['total_attempt'] - train['num_correct']

# %%
train = train[['event_id','game_session','timestamp','event_data','installation_id','event_count','game_time','event_code','title','type','world','num_correct','num_incorrect','total_attempt','accuracy','accuracy_group']]

# %%
for c in ['event_id','timestamp','event_data','event_code','event_count','type']:
    train.pop(c)

# %%
train.to_csv('./../working/train_data.csv',index=False)

# %%
train = pd.read_csv('./../working/train_data.csv')
train.shape
# Out:
# (32743, 11)

# %%
train.head(10)
# Out:
#        game_session installation_id  game_time  title        type  \
# 0  901acc108f55a5a1        0006a69f      31011     37  Assessment
# 1  6bdf9623adc94d89        0006a69f      18026     37  Assessment
# 2  9501794defd84e4d        0006a69f      18484     37  Assessment
# 3  9501794defd84e4d        0006a69f      23043     37  Assessment
# 4  a9ef3ecb3d1acc6a        0006a69f      34209     11  Assessment
# 5  197a373a77101924        0006c192      12635     35  Assessment
# 6  b2297d292892745a        0006c192      32388     37  Assessment
# 7  b2297d292892745a        0006c192      38139     37  Assessment
# 8  b2297d292892745a        0006c192      54974     37  Assessment
# 9  b2297d292892745a        0006c192      79992     37  Assessment
#
#          world  num_correct  num_incorrect  total_attempt  accuracy  \
# 0  TREETOPCITY            1              0              1       1.0
# 1  TREETOPCITY            1              0              1       1.0
# 2  TREETOPCITY            1              1              2       0.5
# 3  TREETOPCITY            1              1              2       0.5
# 4  TREETOPCITY            1              0              1       1.0
# 5    MAGMAPEAK            1              0              1       1.0
# 6  TREETOPCITY            0              4              4       0.0
# 7  TREETOPCITY            0              4              4       0.0
# 8  TREETOPCITY            0              4              4       0.0
# 9  TREETOPCITY            0              4              4       0.0
#
#    accuracy_group
# 0             3.0
# 1             3.0
# 2             2.0
# 3             2.0
# 4             3.0
# 5             3.0
# 6             0.0
# 7             0.0
# 8             0.0
# 9             0.0

# %%
test = test.reset_index(drop=False)
test.drop(columns = ['index'],axis = 1, inplace = True)

# %%
session_count = test['game_session'].value_counts().to_dict()
test['assessment_attempt_count'] = test['game_session'].map(session_count)

# %%
test['contains_true_assessment'] = test['event_data'].map(lambda x: True if (x.find('"correct":true')>=0) else False)

# %%
change_value = {
    True : 1,
    False : 0
}
test['contains_true_assessment'] = test['contains_true_assessment'].map(change_value)

# %%
correct_attempt = dict(test.groupby('game_session',sort=False)['contains_true_assessment'].sum())
test['contains_true_assessment_count'] = test['game_session'].map(correct_attempt)

# %%
for c in ['contains_true_assessment']:
    test.pop(c)

# %%
test['accumulated_accuracy'] = np.where((test['contains_true_assessment_count'] == 0),0,(test['contains_true_assessment_count']/test['assessment_attempt_count']))

# %%
test.loc[(test['type'] == 'Assessment'), 'accuracy_group'] = 0
test.loc[(test['accumulated_accuracy'] == 1) & (test['type'] == 'Assessment'), 'accuracy_group'] = 3
test.loc[(test['accumulated_accuracy'] == 0.5) & (test['type'] == 'Assessment'), 'accuracy_group'] = 2
test.loc[(test['accumulated_accuracy'] < 0.5) & (test['accumulated_accuracy'] > 0) & (test['assessment_attempt_count'] > 0) & (test['type'] == 'Assessment'), 'accuracy_group'] = 1

# %%
test.rename(columns = {'contains_true_assessment_count': 'num_correct',
                        'accumulated_accuracy':'accuracy',
                        'assessment_attempt_count': 'total_attempt'},inplace=True)

# %%
test['num_incorrect'] = test['total_attempt'] - test['num_correct']

# %%
test = test[['event_id','game_session','timestamp','event_data','installation_id','event_count','game_time','event_code','title','type','world','num_correct','num_incorrect','total_attempt','accuracy','accuracy_group']]

# %%
for c in ['event_id','timestamp','event_data','event_code','event_count','type']:
    test.pop(c)

# %%
test.to_csv('./../working/test_data.csv',index=False)

# %%
test.head(100)
# Out:
#         game_session installation_id  game_time                         title  \
# 0   8b38fc0d2fd315dc        00abaee7      22737    Cart Balancer (Assessment)
# 1   009c890ce6c4f3e3        01242218      11474  Cauldron Filler (Assessment)
# 2   009c890ce6c4f3e3        01242218      19775  Cauldron Filler (Assessment)
# 3   e8e62de939f916bc        01242218       8504    Cart Balancer (Assessment)
# 4   ab61cae5e3215355        01242218      13935     Chest Sorter (Assessment)
# 5   ab61cae5e3215355        01242218      28219     Chest Sorter (Assessment)
# 6   ab61cae5e3215355        01242218      51687     Chest Sorter (Assessment)
# 7   31423dbcd717919e        01242218      22479  Mushroom Sorter (Assessment)
# 8   31423dbcd717919e        01242218      29958  Mushroom Sorter (Assessment)
# 9   597a8839a5a3468d        01242218      14080    Bird Measurer (Assessment)
# 10  597a8839a5a3468d        01242218      27829    Bird Measurer (Assessment)
# 11  597a8839a5a3468d        01242218      34947    Bird Measurer (Assessment)
# 12  fec14d065240b4f6        02256298      20104    Cart Balancer (Assessment)
# 13  6520872477535421        027e7ce5       8789  Cauldron Filler (Assessment)
# 14  3d26b3bb6eebb604        027e7ce5      82122    Cart Balancer (Assessment)
# 15  7a1f5c2104692080        027e7ce5      25266     Chest Sorter (Assessment)
# 16  4e6f78563fb62942        027e7ce5      25536  Mushroom Sorter (Assessment)
# 17  5079b43514b68057        027e7ce5      17306    Bird Measurer (Assessment)
# 18  8f703d160f114953        027e7ce5      12516  Cauldron Filler (Assessment)
# 19  8f703d160f114953        027e7ce5      17214  Cauldron Filler (Assessment)
# 20  8f703d160f114953        027e7ce5      25631  Cauldron Filler (Assessment)
# 21  9aefef9dd7269673        027e7ce5      40082  Mushroom Sorter (Assessment)
# 22  dc1c979f6c9ad39c        02a29f99      25766    Bird Measurer (Assessment)
# 23  dc1c979f6c9ad39c        02a29f99      37073    Bird Measurer (Assessment)
# 24  c043d48e6b03550b        02a29f99       9725    Bird Measurer (Assessment)
# 25  c043d48e6b03550b        02a29f99      18209    Bird Measurer (Assessment)
# 26  c043d48e6b03550b        02a29f99      23809    Bird Measurer (Assessment)
# 27  c043d48e6b03550b        02a29f99      27243    Bird Measurer (Assessment)
# 28  c043d48e6b03550b        02a29f99      38610    Bird Measurer (Assessment)
# 69  6d556d42e597f1b0        0617500d       8269    Cart Balancer (Assessment)
# 70  22986381b770dc80        0617500d      16576     Chest Sorter (Assessment)
# 71  30922a5957a8c9e7        0617500d       7965    Cart Balancer (Assessment)
# 72  bf01f1497abb13ad        07749e99      10176    Cart Balancer (Assessment)
# 73  bf01f1497abb13ad        07749e99      33511    Cart Balancer (Assessment)
# 74  bf01f1497abb13ad        07749e99      47612    Cart Balancer (Assessment)
# 75  bf01f1497abb13ad        07749e99      52579    Cart Balancer (Assessment)
# 76  bf01f1497abb13ad        07749e99      77981    Cart Balancer (Assessment)
# 77  bf01f1497abb13ad        07749e99      92653    Cart Balancer (Assessment)
# 78  a0708fb533b66c13        07749e99      33073     Chest Sorter (Assessment)
# 79  a0708fb533b66c13        07749e99      44790     Chest Sorter (Assessment)
# 80  a0708fb533b66c13        07749e99      58858     Chest Sorter (Assessment)
# 81  1bd6ea8f93f35d08        07749e99      10398  Cauldron Filler (Assessment)
# 82  9f9d3354bf509059        07749e99      32072  Mushroom Sorter (Assessment)
# 83  d3beff4c9e75dd79        07749e99      20082    Bird Measurer (Assessment)
# 84  d3beff4c9e75dd79        07749e99      35899    Bird Measurer (Assessment)
# 85  0160ef7f1d3170a9        07749e99      14167    Bird Measurer (Assessment)
# 86  cb1b40d6e679563f        07749e99      13854  Cauldron Filler (Assessment)
# 87  316bdd1509f370b9        07749e99       7921  Cauldron Filler (Assessment)
# 88  29b08213bfbf5e27        08611cc8      17607     Chest Sorter (Assessment)
# 89  96ea064fc22edb96        090fe325      46510     Chest Sorter (Assessment)
# 90  96ea064fc22edb96        090fe325      48661     Chest Sorter (Assessment)
# 91  96ea064fc22edb96        090fe325     166638     Chest Sorter (Assessment)
# 92  96ea064fc22edb96        090fe325     174721     Chest Sorter (Assessment)
# 93  96ea064fc22edb96        090fe325     176988     Chest Sorter (Assessment)
# 94  96ea064fc22edb96        090fe325     197291     Chest Sorter (Assessment)
# 95  96ea064fc22edb96        090fe325     208893     Chest Sorter (Assessment)
# 96  96ea064fc22edb96        090fe325     218232     Chest Sorter (Assessment)
# 97  96ea064fc22edb96        090fe325     222276     Chest Sorter (Assessment)
# 98  2c615e50624459bf        090fe325       5631     Chest Sorter (Assessment)
# 99  2c615e50624459bf        090fe325      93705     Chest Sorter (Assessment)
#
#            world  num_correct  num_incorrect  total_attempt  accuracy  \
# 0   CRYSTALCAVES            1              0              1  1.000000
# 1      MAGMAPEAK            1              1              2  0.500000
# 2      MAGMAPEAK            1              1              2  0.500000
# 3   CRYSTALCAVES            1              0              1  1.000000
# 4   CRYSTALCAVES            0              3              3  0.000000
# 5   CRYSTALCAVES            0              3              3  0.000000
# 6   CRYSTALCAVES            0              3              3  0.000000
# 7    TREETOPCITY            1              1              2  0.500000
# 8    TREETOPCITY            1              1              2  0.500000
# 9    TREETOPCITY            1              2              3  0.333333
# 10   TREETOPCITY            1              2              3  0.333333
# 11   TREETOPCITY            1              2              3  0.333333
# 12  CRYSTALCAVES            1              0              1  1.000000
# 13     MAGMAPEAK            1              0              1  1.000000
# 14  CRYSTALCAVES            1              0              1  1.000000
# 15  CRYSTALCAVES            1              0              1  1.000000
# 16   TREETOPCITY            1              0              1  1.000000
# 17   TREETOPCITY            1              0              1  1.000000
# 18     MAGMAPEAK            1              2              3  0.333333
# 19     MAGMAPEAK            1              2              3  0.333333
# 20     MAGMAPEAK            1              2              3  0.333333
# 21   TREETOPCITY            1              0              1  1.000000
# 22   TREETOPCITY            0              2              2  0.000000
# 23   TREETOPCITY            0              2              2  0.000000
# 24   TREETOPCITY            0             11             11  0.000000
# 25   TREETOPCITY            0             11             11  0.000000
# 26   TREETOPCITY            0             11             11  0.000000
# 27   TREETOPCITY            0             11             11  0.000000
# 28   TREETOPCITY            0             11             11  0.000000
# 29   TREETOPCITY            0             11             11  0.000000
# 30   TREETOPCITY            0             11             11  0.000000
# 31   TREETOPCITY            0             11             11  0.000000
# 32   TREETOPCITY            0             11             11  0.000000
# 33   TREETOPCITY            0             11             11  0.000000
# 34   TREETOPCITY            0             11             11  0.000000
# 35     MAGMAPEAK            1              1              2  0.500000
# 36     MAGMAPEAK            1              1              2  0.500000
# 37   TREETOPCITY            1              0              1  1.000000
# 38  CRYSTALCAVES            1              0              1  1.000000
# 39   TREETOPCITY            1              0              1  1.000000
# 40     MAGMAPEAK            1              0              1  1.000000
# 41  CRYSTALCAVES            1              0              1  1.000000
# 42  CRYSTALCAVES            1              2              3  0.333333
# 43  CRYSTALCAVES            1              2              3  0.333333
# 44  CRYSTALCAVES            1              2              3  0.333333
# 45     MAGMAPEAK            1              0              1  1.000000
# 46   TREETOPCITY            1              0              1  1.000000
# 47   TREETOPCITY            0              4              4  0.000000
# 48   TREETOPCITY            0              4              4  0.000000
# 49   TREETOPCITY            0              4              4  0.000000
# 50   TREETOPCITY            0              4              4  0.000000
# 51     MAGMAPEAK            1              0              1  1.000000
# 52  CRYSTALCAVES            1              0              1  1.000000
# 53  CRYSTALCAVES            0              3              3  0.000000
# 54  CRYSTALCAVES            0              3              3  0.000000
# 55  CRYSTALCAVES            0              3              3  0.000000
# 56   TREETOPCITY            1              0              1  1.000000
# 57   TREETOPCITY            1              2              3  0.333333
# 58   TREETOPCITY            1              2              3  0.333333
# 59   TREETOPCITY            1              2              3  0.333333
# 60  CRYSTALCAVES            1              0              1  1.000000
# 61  CRYSTALCAVES            0              2              2  0.000000
# 62  CRYSTALCAVES            0              2              2  0.000000
# 63   TREETOPCITY            1              0              1  1.000000
# 64   TREETOPCITY            1              0              1  1.000000
# 65     MAGMAPEAK            1              0              1  1.000000
# 66  CRYSTALCAVES            1              0              1  1.000000
# 67  CRYSTALCAVES            0              2              2  0.000000
# 68  CRYSTALCAVES            0              2              2  0.000000
# 69  CRYSTALCAVES            1              0              1  1.000000
# 70  CRYSTALCAVES            0              1              1  0.000000
# 71  CRYSTALCAVES            1              0              1  1.000000
# 72  CRYSTALCAVES            1              5              6  0.166667
# 73  CRYSTALCAVES            1              5              6  0.166667
# 74  CRYSTALCAVES            1              5              6  0.166667
# 75  CRYSTALCAVES            1              5              6  0.166667
# 76  CRYSTALCAVES            1              5              6  0.166667
# 77  CRYSTALCAVES            1              5              6  0.166667
# 78  CRYSTALCAVES            0              3              3  0.000000
# 79  CRYSTALCAVES            0              3              3  0.000000
# 80  CRYSTALCAVES            0              3              3  0.000000
# 81     MAGMAPEAK            1              0              1  1.000000
# 82   TREETOPCITY            1              0              1  1.000000
# 83   TREETOPCITY            1              1              2  0.500000
# 84   TREETOPCITY            1              1              2  0.500000
# 85   TREETOPCITY            1              0              1  1.000000
# 86     MAGMAPEAK            1              0              1  1.000000
# 87     MAGMAPEAK            1              0              1  1.000000
# 88  CRYSTALCAVES            0              1              1  0.000000
# 89  CRYSTALCAVES            0              9              9  0.000000
# 90  CRYSTALCAVES            0              9              9  0.000000
# 91  CRYSTALCAVES            0              9              9  0.000000
# 92  CRYSTALCAVES            0              9              9  0.000000
# 93  CRYSTALCAVES            0              9              9  0.000000
# 94  CRYSTALCAVES            0              9              9  0.000000
# 95  CRYSTALCAVES            0              9              9  0.000000
# 96  CRYSTALCAVES            0              9              9  0.000000
# 97  CRYSTALCAVES            0              9              9  0.000000
# 98  CRYSTALCAVES            0              2              2  0.000000
# 99  CRYSTALCAVES            0              2              2  0.000000
#
#     accuracy_group
# 0              3.0
# 1              2.0
# 2              2.0
# 3              3.0
# 4              0.0
# 5              0.0
# 6              0.0
# 7              2.0
# 8              2.0
# 9              1.0
# 10             1.0
# 11             1.0
# 12             3.0
# 13             3.0
# 14             3.0
# 15             3.0
# 16             3.0
# 17             3.0
# 18             1.0
# 19             1.0
# 20             1.0
# 21             3.0
# 22             0.0
# 23             0.0
# 24             0.0
# 25             0.0
# 26             0.0
# 27             0.0
# 28             0.0
# 29             0.0
# 30             0.0
# 31             0.0
# 32             0.0
# 33             0.0
# 34             0.0
# 35             2.0
# 36             2.0
# 37             3.0
# 38             3.0
# 39             3.0
# 40             3.0
# 41             3.0
# 42             1.0
# 43             1.0
# 44             1.0
# 45             3.0
# 46             3.0
# 47             0.0
# 48             0.0
# 49             0.0
# 50             0.0
# 51             3.0
# 52             3.0
# 53             0.0
# 54             0.0
# 55             0.0
# 56             3.0
# 57             1.0
# 58             1.0
# 59             1.0
# 60             3.0
# 61             0.0
# 62             0.0
# 63             3.0
# 64             3.0
# 65             3.0
# 66             3.0
# 67             0.0
# 68             0.0
# 69             3.0
# 70             0.0
# 71             3.0
# 72             1.0
# 73             1.0
# 74             1.0
# 75             1.0
# 76             1.0
# 77             1.0
# 78             0.0
# 79             0.0
# 80             0.0
# 81             3.0
# 82             3.0
# 83             2.0
# 84             2.0
# 85             3.0
# 86             3.0
# 87             3.0
# 88             0.0
# 89             0.0
# 90             0.0
# 91             0.0
# 92             0.0
# 93             0.0
# 94             0.0
# 95             0.0
# 96             0.0
# 97             0.0
# 98             0.0
# 99             0.0

# %%
result = dict(test.groupby('installation_id')['accuracy_group'].last())

# %%
t = pd.read_csv('/kaggle/input/data-science-bowl-2019/test.csv')

# %%
fcfdffb6  bb342a8258a1cd81  2019-09-21T11:27:52.957Z
# 3711  5d042115  bb342a8258a1cd81  2019-09-21T11:27:53.049Z
# 3712  fcfdffb6  bb342a8258a1cd81  2019-09-21T11:27:53.125Z
# 3713  a44b10dc  bb342a8258a1cd81  2019-09-21T11:27:53.198Z
# 3714  5d042115  bb342a8258a1cd81  2019-09-21T11:27:53.362Z
# 3715  fcfdffb6  bb342a8258a1cd81  2019-09-21T11:27:53.438Z
# 3716  5d042115  bb342a8258a1cd81  2019-09-21T11:27:53.967Z
# 3717  fcfdffb6  bb342a8258a1cd81  2019-09-21T11:27:54.539Z
# 3718  bbfe0445  bb342a8258a1cd81  2019-09-21T11:27:54.653Z
# 3719  5d042115  bb342a8258a1cd81  2019-09-21T11:27:56.266Z
# 3720  598f4598  bb342a8258a1cd81  2019-09-21T11:28:00.755Z
# 3721  de26c3a6  bb342a8258a1cd81  2019-09-21T11:28:00.766Z
# 3722  5d042115  bb342a8258a1cd81  2019-09-21T11:28:01.266Z
# 3723  fcfdffb6  bb342a8258a1cd81  2019-09-21T11:28:01.336Z
# 3724  5d042115  bb342a8258a1cd81  2019-09-21T11:28:01.450Z
# 3725  fcfdffb6  bb342a8258a1cd81  2019-09-21T11:28:01.457Z
# 3726  5d042115  bb342a8258a1cd81  2019-09-21T11:28:01.605Z
# 3727  fcfdffb6  bb342a8258a1cd81  2019-09-21T11:28:01.654Z
# 3728  5d042115  bb342a8258a1cd81  2019-09-21T11:28:01.782Z
# 3729  fcfdffb6  bb342a8258a1cd81  2019-09-21T11:28:01.841Z
# 3730  a44b10dc  bb342a8258a1cd81  2019-09-21T11:28:01.911Z
# 3731  5d042115  bb342a8258a1cd81  2019-09-21T11:28:02.081Z
# 3732  fcfdffb6  bb342a8258a1cd81  2019-09-21T11:28:02.171Z
# 3733  5d042115  bb342a8258a1cd81  2019-09-21T11:28:02.230Z
# 3734  fcfdffb6  bb342a8258a1cd81  2019-09-21T11:28:02.407Z
# 3735  a44b10dc  bb342a8258a1cd81  2019-09-21T11:28:02.516Z
# 3736  3bfd1a65  4b165a330a0bdd6c  2019-09-21T11:28:21.757Z
#
#                                              event_data installation_id  \
# 3587             {"event_code": 2000, "event_count": 1}        017c5718
# 3588             {"event_code": 2000, "event_count": 1}        017c5718
# 3589             {"event_code": 2000, "event_count": 1}        017c5718
# 3590             {"event_code": 2000, "event_count": 1}        017c5718
# 3591             {"event_code": 2000, "event_count": 1}        017c5718
# 3592  {"version":"1.0","event_count":1,"game_time":0...        017c5718
# 3593  {"description":"Let's set off these fireworks....        017c5718
# 3594  {"rocket":1,"coordinates":{"x":128,"y":614,"st...        017c5718
# 3595  {"description":"Let's set off these fireworks....        017c5718
# 3596  {"rocket":1,"height":562,"duration":3866,"coor...        017c5718
# 3597  {"description":"Great job! You did it.","ident...        017c5718
# 3598  {"description":"Great job! You did it.","ident...        017c5718
# 3599  {"rocket":1,"coordinates":{"x":113,"y":615,"st...        017c5718
# 3600  {"rocket":2,"coordinates":{"x":231,"y":622,"st...        017c5718
# 3601  {"rocket":2,"height":566,"duration":2933,"coor...        017c5718
# 3602  {"description":"That one was so low!","identif...        017c5718
# 3603  {"description":"That one was so low!","identif...        017c5718
# 3604  {"description":"That one was so low!","identif...        017c5718
# 3605  {"description":"That one was so low!","identif...        017c5718
# 3606  {"rocket":1,"coordinates":{"x":117,"y":611,"st...        017c5718
# 3607  {"rocket":1,"height":517,"duration":1599,"coor...        017c5718
# 3608  {"description":"That one was so low!","identif...        017c5718
# 3609  {"rocket":2,"coordinates":{"x":231,"y":598,"st...        017c5718
# 3610  {"description":"That one was so low!","identif...        017c5718
# 3611  {"description":"When you're all done, tap this...        017c5718
# 3612  {"rocket":2,"height":518,"duration":1700,"coor...        017c5718
# 3613  {"description":"When you're all done, tap this...        017c5718
# 3614  {"description":"That one was so low!","identif...        017c5718
# 3615  {"rocket":3,"coordinates":{"x":342,"y":619,"st...        017c5718
# 3616  {"description":"That one was so low!","identif...        017c5718
# 3617  {"rocket":3,"height":539,"duration":2483,"coor...        017c5718
# 3618  {"description":"Go higher!","identifier":"Dot_...        017c5718
# 3619  {"description":"Go higher!","identifier":"Dot_...        017c5718
# 3620  {"rocket":3,"coordinates":{"x":325,"y":609,"st...        017c5718
# 3621  {"rocket":1,"coordinates":{"x":122,"y":618,"st...        017c5718
# 3622  {"rocket":1,"height":141,"duration":3316,"coor...        017c5718
# 3623  {"description":"Go higher!","identifier":"Dot_...        017c5718
# 3624  {"description":"Go higher!","identifier":"Dot_...        017c5718
# 3625  {"description":"Go higher!","identifier":"Dot_...        017c5718
# 3626  {"description":"Go higher!","identifier":"Dot_...        017c5718
# 3627  {"rocket":4,"coordinates":{"x":424,"y":636,"st...        017c5718
# 3628  {"coordinates":{"x":204,"y":636,"stage_width":...        017c5718
# 3629  {"coordinates":{"x":301,"y":650,"stage_width":...        017c5718
# 3630  {"rocket":3,"coordinates":{"x":312,"y":635,"st...        017c5718
# 3631  {"rocket":3,"height":17,"duration":4634,"coord...        017c5718
# 3632  {"description":"Go higher!","identifier":"Dot_...        017c5718
# 3633  {"description":"Go higher!","identifier":"Dot_...        017c5718
# 3634  {"description":"Whoa that one was so high!","i...        017c5718
# 3635  {"rocket":4,"coordinates":{"x":427,"y":611,"st...        017c5718
# 3636  {"description":"Whoa that one was so high!","i...        017c5718
# 3637  {"rocket":4,"height":307,"duration":566,"coord...        017c5718
# 3638  {"description":"Whoa so cool!","identifier":"D...        017c5718
# 3639  {"rocket":5,"coordinates":{"x":522,"y":627,"st...        017c5718
# 3640  {"rocket":5,"height":247,"duration":833,"coord...        017c5718
# 3641  {"description":"Whoa so cool!","identifier":"D...        017c5718
# 3642  {"description":"Amazing!","identifier":"Dot_Am...        017c5718
# 3643  {"description":"Amazing!","identifier":"Dot_Am...        017c5718
# 3644  {"rocket":1,"coordinates":{"x":117,"y":647,"st...        017c5718
# 3645  {"coordinates":{"x":499,"y":637,"stage_width":...        017c5718
# 3646  {"coordinates":{"x":502,"y":582,"stage_width":...        017c5718
# 3647  {"rocket":5,"coordinates":{"x":512,"y":636,"st...        017c5718
# 3648  {"rocket":5,"height":358,"duration":3866,"coor...        017c5718
# 3649  {"description":"Whoa so cool!","identifier":"D...        017c5718
# 3650  {"description":"Whoa so cool!","identifier":"D...        017c5718
# 3651  {"description":"Wow!","identifier":"Dot_Wow","...        017c5718
# 3652  {"coordinates":{"x":404,"y":645,"stage_width":...        017c5718
# 3653  {"coordinates":{"x":637,"y":625,"stage_width":...        017c5718
# 3654  {"description":"Wow!","identifier":"Dot_Wow","...        017c5718
# 3655  {"rocket":6,"coordinates":{"x":609,"y":612,"st...        017c5718
# 3656  {"coordinates":{"x":404,"y":636,"stage_width":...        017c5718
# 3657  {"rocket":4,"coordinates":{"x":417,"y":665,"st...        017c5718
# 3658  {"rocket":6,"height":371,"duration":1733,"coor...        017c5718
# 3659  {"description":"Wow!","identifier":"Dot_Wow","...        017c5718
# 3660  {"description":"Wow!","identifier":"Dot_Wow","...        017c5718
# 3661  {"description":"Wow!","identifier":"Dot_Wow","...        017c5718
# 3662  {"description":"Wow!","identifier":"Dot_Wow","...        017c5718
# 3663  {"coordinates":{"x":98,"y":73,"stage_width":10...        017c5718
# 3664             {"event_code": 2000, "event_count": 1}        017c5718
# 3665  {"version":"1.0","event_count":1,"game_time":0...        017c5718
# 3666  {"description":"Welcome to the garden! Which c...        017c5718
# 3667  {"flowers":[0,0,0,0,0],"flower":0,"coordinates...        017c5718
# 3668  {"description":"Welcome to the garden! Which c...        017c5718
# 3669  {"description":"When you're all done, tap this...        017c5718
# 3670  {"description":"When you're all done, tap this...        017c5718
# 3671  {"description":"If you want to pick a flower, ...        017c5718
# 3672  {"coordinates":{"x":368,"y":468,"stage_width":...        017c5718
# 3673  {"growth":[8,8,8,8,8],"flowers":[8,8,8,8,8],"d...        017c5718
# 3674  {"description":"If you want to pick a flower, ...        017c5718
# 3675  {"coordinates":{"x":781,"y":321,"stage_width":...        017c5718
# 3676  {"flowers":[8,8,8,8,8],"flower":5,"coordinates...        017c5718
# 3677  {"description":"Whoa-oh! That is one tall flow...        017c5718
# 3678  {"flower":5,"flowers":[8,8,8,8,0],"coordinates...        017c5718
# 3679  {"flowers":[8,8,8,8,0],"flower":4,"coordinates...        017c5718
# 3680  {"flower":4,"flowers":[8,8,8,0,0],"coordinates...        017c5718
# 3681  {"flowers":[8,8,8,4,0],"flower":3,"coordinates...        017c5718
# 3682  {"flower":3,"flowers":[8,8,0,3,0],"coordinates...        017c5718
# 3683  {"flowers":[8,8,3,0,0],"flower":2,"coordinates...        017c5718
# 3684  {"flower":2,"flowers":[8,0,3,0,0],"coordinates...        017c5718
# 3685  {"flowers":[8,5,1,0,0],"flower":1,"coordinates...        017c5718
# 3686  {"flower":1,"flowers":[7,4,0,0,0],"coordinates...        017c5718
# 3687  {"flowers":[6,3,0,0,0],"flower":1,"coordinates...        017c5718
# 3688  {"flower":1,"flowers":[5,2,0,0,0],"coordinates...        017c5718
# 3689  {"description":"Whoa-oh! That is one tall flow...        017c5718
# 3690  {"description":"You have a green thumb - which...        017c5718
# 3691  {"description":"You have a green thumb - which...        017c5718
# 3692  {"flowers":[0,0,0,0,0],"flower":0,"coordinates...        017c5718
# 3693  {"coordinates":{"x":887,"y":541,"stage_width":...        017c5718
# 3694  {"growth":[0,0,0,0,3],"flowers":[0,0,0,0,3],"d...        017c5718
# 3695  {"flowers":[0,0,0,0,4],"flower":5,"coordinates...        017c5718
# 3696  {"flower":5,"flowers":[0,0,0,0,0],"coordinates...        017c5718
# 3697  {"flowers":[0,0,0,0,0],"flower":0,"coordinates...        017c5718
# 3698  {"coordinates":{"x":420,"y":339,"stage_width":...        017c5718
# 3699  {"growth":[4,4,5,4,3],"flowers":[4,4,5,4,3],"d...        017c5718
# 3700  {"description":"This garden is plant-astic!","...        017c5718
# 3701  {"flowers":[5,4,5,4,3],"flower":2,"coordinates...        017c5718
# 3702  {"flower":2,"flowers":[5,0,5,4,3],"coordinates...        017c5718
# 3703  {"coordinates":{"x":436,"y":414,"stage_width":...        017c5718
# 3704  {"flowers":[5,3,5,4,3],"flower":1,"coordinates...        017c5718
# 3705  {"flower":1,"flowers":[5,2,5,4,3],"coordinates...        017c5718
# 3706  {"flowers":[4,2,5,4,3],"flower":3,"coordinates...        017c5718
# 3707  {"coordinates":{"x":247,"y":351,"stage_width":...        017c5718
# 3708  {"flower":3,"flowers":[3,1,0,4,3],"coordinates...        017c5718
# 3709  {"flowers":[2,1,4,4,3],"flower":3,"coordinates...        017c5718
# 3710  {"flower":3,"flowers":[1,0,0,4,3],"coordinates...        017c5718
# 3711  {"flowers":[0,0,2,4,3],"flower":3,"coordinates...        017c5718
# 3712  {"flower":3,"flowers":[0,0,0,4,3],"coordinates...        017c5718
# 3713  {"coordinates":{"x":733,"y":436,"stage_width":...        017c5718
# 3714  {"flowers":[0,0,0,4,3],"flower":5,"coordinates...        017c5718
# 3715  {"flower":5,"flowers":[0,0,0,4,0],"coordinates...        017c5718
# 3716  {"flowers":[0,0,0,4,0],"flower":4,"coordinates...        017c5718
# 3717  {"flower":4,"flowers":[0,0,0,0,0],"coordinates...        017c5718
# 3718  {"description":"This garden is plant-astic!","...        017c5718
# 3719  {"flowers":[0,0,0,0,0],"flower":0,"coordinates...        017c5718
# 3720  {"coordinates":{"x":1013,"y":469,"stage_width"...        017c5718
# 3721  {"growth":[3,4,4,4,5],"flowers":[3,4,4,4,5],"d...        017c5718
# 3722  {"flowers":[3,4,4,4,5],"flower":1,"coordinates...        017c5718
# 3723  {"flower":1,"flowers":[3,4,4,4,5],"coordinates...        017c5718
# 3724  {"flowers":[2,4,4,4,5],"flower":1,"coordinates...        017c5718
# 3725  {"flower":1,"flowers":[2,4,4,4,5],"coordinates...        017c5718
# 3726  {"flowers":[1,4,4,4,5],"flower":2,"coordinates...        017c5718
# 3727  {"flower":2,"flowers":[1,0,4,4,5],"coordinates...        017c5718
# 3728  {"flowers":[1,3,4,4,5],"flower":3,"coordinates...        017c5718
# 3729  {"flower":3,"flowers":[0,2,0,4,5],"coordinates...        017c5718
# 3730  {"coordinates":{"x":597,"y":409,"stage_width":...        017c5718
# 3731  {"flowers":[0,0,2,4,5],"flower":4,"coordinates...        017c5718
# 3732  {"flower":4,"flowers":[0,0,1,0,5],"coordinates...        017c5718
# 3733  {"flowers":[0,0,0,3,5],"flower":5,"coordinates...        017c5718
# 3734  {"flower":5,"flowers":[0,0,0,1,0],"coordinates...        017c5718
# 3735  {"coordinates":{"x":804,"y":358,"stage_width":...        017c5718
# 3736  {"version":"1.0","event_count":1,"game_time":0...        017c5718
#
#       event_count  event_code  game_time                         title  \
# 3587            1        2000          0       Welcome to Lost Lagoon!
# 3588            1        2000          0       Welcome to Lost Lagoon!
# 3589            1        2000          0       Welcome to Lost Lagoon!
# 3590            1        2000          0       Welcome to Lost Lagoon!
# 3591            1        2000          0       Tree Top City - Level 1
# 3592            1        2000          0          Fireworks (Activity)
# 3593            2        3010          0          Fireworks (Activity)
# 3594            3        4030       2081          Fireworks (Activity)
# 3595            4        3110       4014          Fireworks (Activity)
# 3596            5        4020       5947          Fireworks (Activity)
# 3597            6        3010       6897          Fireworks (Activity)
# 3598            7        3110       8580          Fireworks (Activity)
# 3599            8        4030       9097          Fireworks (Activity)
# 3600            9        4030       9097          Fireworks (Activity)
# 3601           10        4020      12030          Fireworks (Activity)
# 3602           11        3010      12980          Fireworks (Activity)
# 3603           12        3110      12997          Fireworks (Activity)
# 3604           13        3010      12997          Fireworks (Activity)
# 3605           14        3110      14480          Fireworks (Activity)
# 3606           15        4030      15197          Fireworks (Activity)
# 3607           16        4020      16796          Fireworks (Activity)
# 3608           17        3010      17796          Fireworks (Activity)
# 3609           18        4030      18746          Fireworks (Activity)
# 3610           19        3110      18913          Fireworks (Activity)
# 3611           20        3010      18913          Fireworks (Activity)
# 3612           21        4020      20446          Fireworks (Activity)
# 3613           22        3110      20929          Fireworks (Activity)
# 3614           23        3010      21463          Fireworks (Activity)
# 3615           24        4030      22179          Fireworks (Activity)
# 3616           25        3110      22946          Fireworks (Activity)
# 3617           26        4020      24662          Fireworks (Activity)
# 3618           27        3010      25629          Fireworks (Activity)
# 3619           28        3110      26412          Fireworks (Activity)
# 3620           29        4030      27279          Fireworks (Activity)
# 3621           30        4030      27279          Fireworks (Activity)
# 3622           31        4020      30595          Fireworks (Activity)
# 3623           32        3010      32162          Fireworks (Activity)
# 3624           34        3010      32179          Fireworks (Activity)
# 3625           33        3110      32179          Fireworks (Activity)
# 3626           35        3110      32945          Fireworks (Activity)
# 3627           36        4030      34028          Fireworks (Activity)
# 3628           37        4070      34095          Fireworks (Activity)
# 3629           38        4070      35978          Fireworks (Activity)
# 3630           39        4030      36862          Fireworks (Activity)
# 3631           40        4020      38662          Fireworks (Activity)
# 3632           41        3010      40428          Fireworks (Activity)
# 3633           42        3110      40461          Fireworks (Activity)
# 3634           43        3010      40461          Fireworks (Activity)
# 3635           44        4030      41945          Fireworks (Activity)
# 3636           45        3110      42394          Fireworks (Activity)
# 3637           46        4020      42511          Fireworks (Activity)
# 3638           47        3010      43844          Fireworks (Activity)
# 3639           48        4030      44811          Fireworks (Activity)
# 3640           49        4020      45644          Fireworks (Activity)
# 3641           50        3110      46161          Fireworks (Activity)
# 3642           51        3010      47044          Fireworks (Activity)
# 3643           52        3110      48194          Fireworks (Activity)
# 3644           53        4030      48511          Fireworks (Activity)
# 3645           54        4070      48594          Fireworks (Activity)
# 3646           55        4070      49577          Fireworks (Activity)
# 3707           43        4070      42174     Flower Waterer (Activity)
# 3708           44        4022      42224     Flower Waterer (Activity)
# 3709           45        4030      42274     Flower Waterer (Activity)
# 3710           46        4022      42357     Flower Waterer (Activity)
# 3711           47        4030      42441     Flower Waterer (Activity)
# 3712           48        4022      42524     Flower Waterer (Activity)
# 3713           49        4070      42591     Flower Waterer (Activity)
# 3714           50        4030      42757     Flower Waterer (Activity)
# 3715           51        4022      42841     Flower Waterer (Activity)
# 3716           52        4030      43357     Flower Waterer (Activity)
# 3717           53        4022      43941     Flower Waterer (Activity)
# 3718           54        3110      44041     Flower Waterer (Activity)
# 3719           55        4030      45657     Flower Waterer (Activity)
# 3720           56        4025      50157     Flower Waterer (Activity)
# 3721           57        4020      50157     Flower Waterer (Activity)
# 3722           58        4030      50657     Flower Waterer (Activity)
# 3723           59        4022      50740     Flower Waterer (Activity)
# 3724           60        4030      50840     Flower Waterer (Activity)
# 3725           61        4022      50860     Flower Waterer (Activity)
# 3726           62        4030      50990     Flower Waterer (Activity)
# 3727           63        4022      51057     Flower Waterer (Activity)
# 3728           64        4030      51174     Flower Waterer (Activity)
# 3729           65        4022      51240     Flower Waterer (Activity)
# 3730           66        4070      51307     Flower Waterer (Activity)
# 3731           67        4030      51473     Flower Waterer (Activity)
# 3732           68        4022      51573     Flower Waterer (Activity)
# 3733           69        4030      51623     Flower Waterer (Activity)
# 3734           70        4022      51807     Flower Waterer (Activity)
# 3735           71        4070      51907     Flower Waterer (Activity)
# 3736            1        2000          0  Mushroom Sorter (Assessment)
#
#             type        world
# 3587        Clip         NONE
# 3588        Clip         NONE
# 3589        Clip         NONE
# 3590        Clip         NONE
# 3591        Clip  TREETOPCITY
# 3592    Activity  TREETOPCITY
# 3593    Activity  TREETOPCITY
# 3594    Activity  TREETOPCITY
# 3595    Activity  TREETOPCITY
# 3596    Activity  TREETOPCITY
# 3597    Activity  TREETOPCITY
# 3598    Activity  TREETOPCITY
# 3599    Activity  TREETOPCITY
# 3600    Activity  TREETOPCITY
# 3601    Activity  TREETOPCITY
# 3602    Activity  TREETOPCITY
# 3603    Activity  TREETOPCITY
# 3604    Activity  TREETOPCITY
# 3605    Activity  TREETOPCITY
# 3606    Activity  TREETOPCITY
# 3607    Activity  TREETOPCITY
# 3608    Activity  TREETOPCITY
# 3609    Activity  TREETOPCITY
# 3610    Activity  TREETOPCITY
# 3611    Activity  TREETOPCITY
# 3612    Activity  TREETOPCITY
# 3613    Activity  TREETOPCITY
# 3614    Activity  TREETOPCITY
# 3615    Activity  TREETOPCITY
# 3616    Activity  TREETOPCITY
# 3617    Activity  TREETOPCITY
# 3618    Activity  TREETOPCITY
# 3619    Activity  TREETOPCITY
# 3620    Activity  TREETOPCITY
# 3621    Activity  TREETOPCITY
# 3622    Activity  TREETOPCITY
# 3623    Activity  TREETOPCITY
# 3624    Activity  TREETOPCITY
# 3625    Activity  TREETOPCITY
# 3626    Activity  TREETOPCITY
# 3627    Activity  TREETOPCITY
# 3628    Activity  TREETOPCITY
# 3629    Activity  TREETOPCITY
# 3630    Activity  TREETOPCITY
# 3631    Activity  TREETOPCITY
# 3632    Activity  TREETOPCITY
# 3633    Activity  TREETOPCITY
# 3634    Activity  TREETOPCITY
# 3635    Activity  TREETOPCITY
# 3636    Activity  TREETOPCITY
# 3637    Activity  TREETOPCITY
# 3638    Activity  TREETOPCITY
# 3639    Activity  TREETOPCITY
# 3640    Activity  TREETOPCITY
# 3641    Activity  TREETOPCITY
# 3642    Activity  TREETOPCITY
# 3643    Activity  TREETOPCITY
# 3644    Activity  TREETOPCITY
# 3645    Activity  TREETOPCITY
# 3646    Activity  TREETOPCITY
# 3647    Activity  TREETOPCITY
# 3648    Activity  TREETOPCITY
# 3649    Activity  TREETOPCITY
# 3650    Activity  TREETOPCITY
# 3651    Activity  TREETOPCITY
# 3652    Activity  TREETOPCITY
# 3653    Activity  TREETOPCITY
# 3654    Activity  TREETOPCITY
# 3655    Activity  TREETOPCITY
# 3656    Activity  TREETOPCITY
# 3657    Activity  TREETOPCITY
# 3658    Activity  TREETOPCITY
# 3659    Activity  TREETOPCITY
# 3660    Activity  TREETOPCITY
# 3661    Activity  TREETOPCITY
# 3662    Activity  TREETOPCITY
# 3663    Activity  TREETOPCITY
# 3664        Clip  TREETOPCITY
# 3665    Activity  TREETOPCITY
# 3666    Activity  TREETOPCITY
# 3667    Activity  TREETOPCITY
# 3668    Activity  TREETOPCITY
# 3669    Activity  TREETOPCITY
# 3670    Activity  TREETOPCITY
# 3671    Activity  TREETOPCITY
# 3672    Activity  TREETOPCITY
# 3673    Activity  TREETOPCITY
# 3674    Activity  TREETOPCITY
# 3675    Activity  TREETOPCITY
# 3676    Activity  TREETOPCITY
# 3677    Activity  TREETOPCITY
# 3678    Activity  TREETOPCITY
# 3679    Activity  TREETOPCITY
# 3680    Activity  TREETOPCITY
# 3681    Activity  TREETOPCITY
# 3682    Activity  TREETOPCITY
# 3683    Activity  TREETOPCITY
# 3684    Activity  TREETOPCITY
# 3685    Activity  TREETOPCITY
# 3686    Activity  TREETOPCITY
# 3687    Activity  TREETOPCITY
# 3688    Activity  TREETOPCITY
# 3689    Activity  TREETOPCITY
# 3690    Activity  TREETOPCITY
# 3691    Activity  TREETOPCITY
# 3692    Activity  TREETOPCITY
# 3693    Activity  TREETOPCITY
# 3694    Activity  TREETOPCITY
# 3695    Activity  TREETOPCITY
# 3696    Activity  TREETOPCITY
# 3697    Activity  TREETOPCITY
# 3698    Activity  TREETOPCITY
# 3699    Activity  TREETOPCITY
# 3700    Activity  TREETOPCITY
# 3701    Activity  TREETOPCITY
# 3702    Activity  TREETOPCITY
# 3703    Activity  TREETOPCITY
# 3704    Activity  TREETOPCITY
# 3705    Activity  TREETOPCITY
# 3706    Activity  TREETOPCITY
# 3707    Activity  TREETOPCITY
# 3708    Activity  TREETOPCITY
# 3709    Activity  TREETOPCITY
# 3710    Activity  TREETOPCITY
# 3711    Activity  TREETOPCITY
# 3712    Activity  TREETOPCITY
# 3713    Activity  TREETOPCITY
# 3714    Activity  TREETOPCITY
# 3715    Activity  TREETOPCITY
# 3716    Activity  TREETOPCITY
# 3717    Activity  TREETOPCITY
# 3718    Activity  TREETOPCITY
# 3719    Activity  TREETOPCITY
# 3720    Activity  TREETOPCITY
# 3721    Activity  TREETOPCITY
# 3722    Activity  TREETOPCITY
# 3723    Activity  TREETOPCITY
# 3724    Activity  TREETOPCITY
# 3725    Activity  TREETOPCITY
# 3726    Activity  TREETOPCITY
# 3727    Activity  TREETOPCITY
# 3728    Activity  TREETOPCITY
# 3729    Activity  TREETOPCITY
# 3730    Activity  TREETOPCITY
# 3731    Activity  TREETOPCITY
# 3732    Activity  TREETOPCITY
# 3733    Activity  TREETOPCITY
# 3734    Activity  TREETOPCITY
# 3735    Activity  TREETOPCITY
# 3736  Assessment  TREETOPCITY

# %%
pprint.pprint(json.loads(t['event_data'][3731]))
# Out:
# {'coordinates': {'stage_height': 762, 'stage_width': 1015, 'x': 695, 'y': 399},
#  'event_code': 4030,
#  'event_count': 67,
#  'flower': 4,
#  'flowers': [0, 0, 2, 4, 5],
#  'game_time': 51473}

# %%
def make_classifier():
    clf = CatBoostClassifier(
                               loss_function='MultiClass',
                               task_type="CPU",
                               learning_rate=0.01,
                               iterations=100,
                               od_type="Iter",
                               early_stopping_rounds=50,
                               random_seed=2019,
                               colsample_bylevel=0.87,
                               eval_metric='Kappa',
                              )
        
    return clf
oof = np.zeros(len(x))

# %%
params = {
       'loss_function':'MultiClass',
       'task_type':'CPU',
       'learning_rate':0.05,
       'iterations':20,
       'early_stopping_rounds':5,
       'random_seed':89,
       'colsample_bylevel':0.87,
       'eval_metric':'Kappa',
}

# %%
#cat_features = ['Clip','Game','session_title','Activity']

# %%
cat_features = ['Clip']

# %%
oof = np.zeros(len(x))
NFOLDS = 4
folds = KFold(n_splits=NFOLDS)
clf_in_predict = []

for fold, (trn_idx, test_idx) in enumerate(folds.split(x, y)):
    print(f'Training on fold {fold+1}')
    clf = make_classifier()
    clf.fit(x.loc[trn_idx], y.loc[trn_idx], eval_set=(x.loc[test_idx], y.loc[test_idx]),
                          use_best_model=True, verbose=500,cat_features=cat_features)
    
    clf_in_predict = clf.predict(x.loc[test_idx].reshape(len(tets_idx)))
    
    print('-' * 30)
    print('Traning_predict QWK:', quadratic_weight_kappa(y, clf_in_predict))
    print('-' * 30)
    
    oof[test_idx] = clf.predict(x.loc[test_idx]).reshape(len(test_idx))

    
print('-' * 30)
print('OOF QWK:', quadratic_weight_kappa(y, oof))
print('-' * 30)

# %%
# process test set
new_test = []
for ins_id,user_sample in tqdm(test.groupby(['installation_id'], sort=False), total=1000):
    a = get_data(user_sample, test_set=True)
    new_test.append(a)
    
test = pd.DataFrame(new_test)

# %%
test.head()

# %%
preds = clf.predict(test)
del test

# %% [markdown]
# ## Make Submission

# %%
submission['accuracy_group'] = np.round(preds).astype('int')
submission.to_csv('submission.csv', index=None)
submission.head()

# %%
# !rm -rf catboost_info
