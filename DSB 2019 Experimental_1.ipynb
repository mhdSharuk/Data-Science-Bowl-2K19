# %%
import pandas as pd
import numpy as np
import os

# %%
train = pd.read_csv('/kaggle/input/data-science-bowl-2019/train.csv')
train_labels = pd.read_csv('/kaggle/input/data-science-bowl-2019/train_labels.csv')
specs = pd.read_csv('/kaggle/input/data-science-bowl-2019/specs.csv')
test = pd.read_csv('/kaggle/input/data-science-bowl-2019/test.csv')
submission = pd.read_csv('/kaggle/input/data-science-bowl-2019/sample_submission.csv')

# %%
assessment_id = list(train[train['type'] == 'Assessment']['installation_id'].unique())
train = train.loc[train['installation_id'].isin(assessment_id)]

# %%
train = train.reset_index(drop=False)
train.drop(columns = ['index'],axis = 1, inplace = True)

# %%
ids = train[train['installation_id'] == '0006a69f'].shape[0]

# %%
train[train['title'] == 'Slop Problem']
# Out:
# (4256, 11)

# %%
train[train['type'] == 'Clip']['event_code'].unique()
# Out:
# array([2000])

# %%
pprint.pprint(json.loads(train['event_data'][277]))
# Out:
# {'coordinates': {'stage_height': 762, 'stage_width': 1015, 'x': 326, 'y': 731},
#  'dinosaur': 'stacey',
#  'dinosaurs': [{'name': 'none', 'size': 0},
#                {'name': 'buddy', 'size': 3},
#                {'name': 'petey', 'size': 2}],
#  'event_code': 4030,
#  'event_count': 11,
#  'game_time': 12891,
#  'round': 1,
#  'size': 4}

# %%
specs[specs['event_id'] == '27253bdc']
# Out:
#      event_id                                               info  \
# 343  27253bdc  This event is triggered when a video starts pl...
#
#                                                   args
# 343  [{"name":"event_count","type":"int","info":"se...

# %%
specs['info'][343]
# Out:
# 'This event is triggered when a video starts playing'

# %%
train['type'].unique()
# Out:
# array(['Clip', 'Activity', 'Game', 'Assessment'], dtype=object)

# %%
train[train['type'] == 'Clip']['title'].unique()
# Out:
# array(['Welcome to Lost Lagoon!', 'Magma Peak - Level 1', 'Slop Problem',
#        'Tree Top City - Level 1', 'Ordering Spheres', 'Costume Box',
#        '12 Monkeys', 'Tree Top City - Level 2', "Pirate's Tale",
#        'Treasure Map', 'Tree Top City - Level 3', 'Rulers',
#        'Magma Peak - Level 2', 'Crystal Caves - Level 1', 'Balancing Act',
#        'Crystal Caves - Level 2', 'Crystal Caves - Level 3',
#        'Lifting Heavy Things', 'Honey Cake', 'Heavy, Heavier, Heaviest'],
#       dtype=object)
