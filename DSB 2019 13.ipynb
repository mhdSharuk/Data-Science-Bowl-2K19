# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns', None)
import datetime
import catboost
from catboost import CatBoostClassifier,Pool
import time
from tqdm import tqdm_notebook as tqdm
import os
import random
from datetime import timezone, datetime
from bayes_opt import BayesianOptimization
import itertools
from itertools import chain 
import json
import pprint
import gc
import seaborn as sns
from typing import Any
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold, GroupKFold, GridSearchCV, train_test_split, TimeSeriesSplit, RepeatedStratifiedKFold
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import cohen_kappa_score
from collections import Counter
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from sklearn.base import BaseEstimator, TransformerMixin
import lightgbm as lgb
import xgboost as xgb
import copy
from functools import partial
import scipy as sp

# %%
def spec(value,*args):
    i= specs[specs['event_id'] == value].index.values[-1]
    print('Index :',i)
    print('Event_code :',train[train['event_id'] == value]['event_code'].unique()[-1])
    for arg in args:
        if(arg == 'info'):
         print(specs[arg][i])
        elif(arg == 'args'):
         print(pprint.pprint(json.loads(specs[arg][i])))
        else:
         print('Nothing')

# %%
def event(value):
    i = train[train['event_id'] == value].index.values[-1]
    print(pprint.pprint(json.loads(train['event_data'][i])))

# %%
def reset(df):
    df = df.reset_index(drop=False)
    df.drop(columns=['index'],axis=1,inplace=True)
    return df

# %%
def get_features(df):
    total_features = []
    clip_features = ['num_clip_watched']
    game_features = ['4070_count_game','num_unique_games','total_game_actions','total_duration_spend_for_game','total_game_attempts',
                     'total_correct_attempts','last_game_played_accuracy','gaming_accuracy','2030_count','4030_count','chow_time',
                     '3110_count','4035_count','3120_count','2010_count','instructional_waiting_time_game']
    activity_features = ['4070_count_act','instructional_waiting_time_activity']
    assessment_features = ['mushroom','chest','bird','cauldron','cart','assessment_time_spent']
    total_data = {}
    total_features = clip_features + game_features + activity_features + assessment_features
    for i,install_id in tqdm(df.groupby('installation_id',sort=False)):

        clip_data = {eve : 0 for eve in clip_features}
        game_data = {eve : 0 for eve in game_features}
        activity_data = {eve : 0 for eve in activity_features}
        assessment_data =  {eve : 0 for eve in assessment_features}

        for j,session in install_id.groupby('game_session',sort=False):

            session_type = session['type'].iloc[0]
            session_title = session['title'].iloc[0]

            if((session_type == 'Clip')):
                clip_data['num_clip_watched'] += 1
                
            elif(session_type == 'Game'):
                game_data['num_unique_games'] += 1
                game_data['total_game_actions'] += session['event_code'].count()
                game_data['total_duration_spend_for_game'] += int(session['game_time'].iloc[-1]/1000)
                game_data['total_game_attempts'] += session[session['event_code'] == 4020]['event_code'].count()
                game_data['total_correct_attempts'] += session[session['event_code'] == 4020]['event_data'].map(lambda x:1 if(str(x).find('"correct":true') >= 0) else 0).sum()
                #game_data['correct_attempt_time'] += int(session[session['event_code'] == 4020]['game_time'].iloc[-1]/1000)
                #game_data['confused_time'] += int(session[session['event_code'] == 4070]['game_time'].iloc[-1]/1000)
                game_data['gaming_accuracy'] += round((game_data['total_correct_attempts']/game_data['total_game_attempts']),3) if(game_data['total_game_attempts']>0) else 0
                game_data['last_game_played_accuracy'] = round(game_data['total_correct_attempts'] / game_data['total_game_attempts'],3) if(game_data['total_game_attempts']>0) else 0
                game_data['4070_count_game'] += session[session['event_code']==4070]['event_code'].count()
                game_data['2030_count'] += session[session['event_code']==2030]['event_code'].count()
                game_data['4030_count'] += session[session['event_code']==4030]['event_code'].count()
                game_data['chow_time'] += session[session['title'] == 'Chow Time']['title'].count()
                game_data['3110_count'] += session[session['event_code'] == 3110]['event_code'].count()
                game_data['4035_count'] += session[session['event_code'] == 4035]['event_code'].count()
                game_data['3120_count'] += session[session['event_code'] == 3120]['event_code'].count()
                game_data['2010_count'] += session[session['event_code'] == 2010]['event_code'].count()
                game_data['instructional_waiting_time_game'] += session[session['event_code'] == 3010]['event_code'].count()
                #for i in list(set(train['event_code'].unique()).union(set(test['event_code'].unique()))):
                    #event_code_count[f'{i}_count'] += session[session['event_code'] == i].count()
            elif(session_type == 'Activity'):
                activity_data['4070_count_act'] += session[session['event_code'] == 4070]['event_code'].count()
                #activity_data['act_duration'] += int(session['game_time'].iloc[-1]/1000)
                activity_data['instructional_waiting_time_activity'] += session[session['event_code'] == 3010]['event_code'].count()
                #pass
            elif(session_type == 'Assessment'):
                assessment_data['mushroom'] += session[session['title'] == 'Mushroom Sorter (Assessment)']['title'].count()
                assessment_data['chest'] += session[session['title'] == 'Chest Sorter (Assessment)']['title'].count()
                assessment_data['bird'] += session[session['title'] == 'Bird Measurer (Assessment)']['title'].count()
                assessment_data['cauldron'] += session[session['title'] == 'Cauldron Filler (Assessment)']['title'].count()
                assessment_data['cart'] += session[session['title'] == 'Cart Balancer (Assessment)']['title'].count()
                assessment_data['assessment_time_spent'] += int(session['game_time'].iloc[-1]/1000)
                #game_preprocessing
                #game_data['4070_count'] = game_data['4070_count'] + activity_data['4070_count']
                #Activity preprocessing


                #Clip preprocessing



                total_data[j] = {}
                total_data[j].update(clip_data)
                total_data[j].update(activity_data)
                total_data[j].update(game_data)
                total_data[j].update(assessment_data)
                #total_data[j].update(event_code_count)

                clip_data = {eve : 0 for eve in clip_features}
                game_data = {eve : 0 for eve in game_features}
                activity_data = {eve : 0 for eve in activity_features}
                assessment_data = {eve : 0 for eve in assessment_features}
    return total_features,total_data

# %%
def seed_everything(seed=0):
  random.seed(seed)
  os.environ['PYTHONHASHSEED'] = str(seed)
  np.random.seed(seed)

# %%
def Rand(start, end, num): 
    res = [] 
    for j in range(num): 
        res.append(random.randint(start, end)) 
    return res

# %%
def qwk(a1, a2):
    max_rat = 3
    a1 = np.asarray(a1, dtype=int)
    a2 = np.asarray(a2, dtype=int)
    
    hist1 = np.zeros((max_rat + 1, ))
    hist2 = np.zeros((max_rat + 1, ))
    
    o = 0
    for k in range(a1.shape[0]):
        i, j = a1[k], a2[k]
        hist1[i] += 1
        hist2[j] += 1
        o +=  (i - j) * (i - j)

    e = 0
    for i in range(max_rat + 1):
        for j in range(max_rat + 1):
            e += hist1[i] * hist2[j] * (i - j) * (i - j)

    e = e / a1.shape[0]
    return 1 - o / e

# %%
def eval_qwk_lgb(y_true, y_pred):
    y_pred = y_pred.reshape(len(np.unique(y_true)), -1).argmax(axis=0)
    return 'cappa', qwk(y_true, y_pred), True

# %%
#def nelder_mead(y_true,y_pred):
#    print('.')
#    nelder_value = []
#    optimizer = OptimizedRounder()
#    optimizer.fit(y_true.reshape(-1,), y_pred)
#    optimized_value = list(optimizer.coefficients())
#    print(optimized_value)
#    return optimized_value

# %%
#def eval_qwk_lgb_regr(y_true, y_pred):
#    
#    optimized = nelder_mead(y_true,y_pred)
    #print(optimized)
    
#    y_pred[y_pred <= optimized[0]] = 0
#    y_pred[np.where(np.logical_and(y_pred > optimized[0], y_pred <= optimized[1]))] = 1
#    y_pred[np.where(np.logical_and(y_pred > optimized[1], y_pred <= optimized[2]))] = 2
#    y_pred[y_pred > optimized[2]] = 3
    
#    return 'cappa', qwk(y_true, y_pred), True

# %%
def eval_qwk_lgb_regr(y_true, y_pred):
    y_pred[y_pred <= 1.12232214] = 0
    y_pred[np.where(np.logical_and(y_pred > 1.12232214, y_pred <= 1.73925866))] = 1
    y_pred[np.where(np.logical_and(y_pred > 1.73925866, y_pred <= 2.22506454))] = 2
    y_pred[y_pred > 2.22506454] = 3
    
    return 'cappa', qwk(y_true, y_pred), True

# %%
class LGBWrapper_regr(object):
   
    def __init__(self):
        self.model = lgb.LGBMRegressor(**params)
    
    
    def fit(self, X_train, y_train, X_valid=None, y_valid=None, X_holdout=None, y_holdout=None, params=None):
        
        if params['objective'] == 'regression':
            eval_metric = eval_qwk_lgb_regr
        else:
            eval_metric = 'auc'
            
        eval_set = [(X_train, y_train)]
        eval_names = ['train']
        
        self.model = self.model.set_params(**params)

        if X_valid is not None:
            eval_set.append((X_valid, y_valid))
            eval_names.append('valid')

        if X_holdout is not None:
            eval_set.append((X_holdout, y_holdout))
            eval_names.append('holdout')

        if 'cat_cols' in params.keys():
            cat_cols = [col for col in params['cat_cols'] if col in X_train.columns]
            if len(cat_cols) > 0:
                categorical_columns = params['cat_cols']
            else:
                categorical_columns = 'auto'
        else:
            categorical_columns = 'auto'
        self.model.fit(X=X_train, y=y_train,
                       eval_set=eval_set, eval_names=eval_names, eval_metric=eval_metric,
                       verbose=params['verbose'], early_stopping_rounds=params['early_stopping_rounds'],
                       categorical_feature=categorical_columns)         

        self.best_score_ = self.model.best_score_
        self.feature_importances_ = self.model.feature_importances_

    def predict(self, X_test):
        return self.model.predict(X_test, num_iteration=self.model.best_iteration_)

# %%
class RegressorModel(object):

    def __init__(self, columns: list = None, model_wrapper=None):
        
        self.columns = columns
        self.model_wrapper = model_wrapper
        self.result_dict = {}
        self.train_one_fold = False
        self.preprocesser = None

    def fit(self, X: pd.DataFrame, y,
            X_holdout: pd.DataFrame = None, y_holdout=None,
            folds=None,
            params: dict = None,
            eval_metric='rmse',
            cols_to_drop: list = None,
            preprocesser=None,
            transformers: dict = None,
            adversarial: bool = False,
            plot: bool = True):

        if folds is None:
            folds = KFold(n_splits=3, random_state=42)
            self.train_one_fold = True

        self.columns = X.columns if self.columns is None else self.columns
        self.feature_importances = pd.DataFrame(columns=['feature', 'importance'])
        self.trained_transformers = {k: [] for k in transformers}
        self.transformers = transformers
        self.models = []
        self.folds_dict = {}
        self.eval_metric = eval_metric
        n_target = 1
        self.oof = np.zeros((len(X), n_target))
        self.n_target = n_target

        X = X[self.columns]
        if X_holdout is not None:
            X_holdout = X_holdout[self.columns]

        if preprocesser is not None:
            self.preprocesser = preprocesser
            self.preprocesser.fit(X, y)
            X = self.preprocesser.transform(X, y)
            self.columns = X.columns.tolist()
            if X_holdout is not None:
                X_holdout = self.preprocesser.transform(X_holdout)

        for fold_n, (train_index, valid_index) in enumerate(folds.split(X, y, X['installation_id'])):

            if X_holdout is not None:
                X_hold = X_holdout.copy()
            else:
                X_hold = None
            self.folds_dict[fold_n] = {}
            if params['verbose']:
                print(f'Fold {fold_n + 1} started at {time.ctime()}')

            X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
            y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
            if self.train_one_fold:
                X_train = X[self.original_columns]
                y_train = y
                X_valid = None
                y_valid = None

            datasets = {'X_train': X_train, 'X_valid': X_valid, 'X_holdout': X_hold, 'y_train': y_train}
            X_train, X_valid, X_hold = self.transform_(datasets, cols_to_drop)
            #self.columns_used = X_train.columns

            self.folds_dict[fold_n]['columns'] = X_train.columns.tolist()
            if adversarial:
                X_new1 = X_train.copy()
                if X_valid is not None:
                    X_new2 = X_valid.copy()
                elif X_holdout is not None:
                    X_new2 = X_holdout.copy()
                X_new = pd.concat([X_new1, X_new2], axis=0)
                y_new = np.hstack((np.zeros((X_new1.shape[0])), np.ones((X_new2.shape[0]))))
                X_train, X_valid, y_train, y_valid = train_test_split(X_new, y_new)
             
            self.X_train = X_train
            self.y_train = y_train
            self.X_valid = X_valid
            self.y_valid = y_valid
            self.X_holdout = X_holdout
            self.y_holdout = y_holdout
            model = copy.deepcopy(self.model_wrapper)  
            model.fit(X_train, y_train, X_valid, y_valid, X_hold, y_holdout, params=params)                                   
                                                                                                                                            
            self.folds_dict[fold_n]['scores'] = model.best_score_
            if self.oof.shape[0] != len(X):
                self.oof = np.zeros((X.shape[0], self.oof.shape[1]))
            if not adversarial:
                self.oof[valid_index] = model.predict(X_valid).reshape(-1, n_target)
            fold_importance = pd.DataFrame(list(zip(X_train.columns, model.feature_importances_)),
                                           columns=['feature', 'importance'])
            self.feature_importances = self.feature_importances.append(fold_importance)
            self.models.append(model)

        self.feature_importances['importance'] = self.feature_importances['importance'].astype(int)

        self.calc_scores_()
        if plot:
            fig, ax = plt.subplots(figsize=(16, 12))
            plt.subplot(2, 2, 1)
            self.plot_feature_importance(top_n=20)
            plt.subplot(2, 2, 2)
            self.plot_metric()
            plt.subplot(2, 2, 3)
            plt.hist(y.values.reshape(-1, 1) - self.oof)
            plt.title('Distribution of errors')
            plt.subplot(2, 2, 4)
            plt.hist(self.oof)
            plt.title('Distribution of oof predictions');

    def transform_(self, datasets, cols_to_drop):
        for name, transformer in self.transformers.items():
            transformer.fit(datasets['X_train'], datasets['y_train'])
            datasets['X_train'] = transformer.transform(datasets['X_train'])
            if datasets['X_valid'] is not None:
                datasets['X_valid'] = transformer.transform(datasets['X_valid'])
            if datasets['X_holdout'] is not None:
                datasets['X_holdout'] = transformer.transform(datasets['X_holdout'])
            self.trained_transformers[name].append(transformer)
        if cols_to_drop is not None:
            cols_to_drop = [col for col in cols_to_drop if col in datasets['X_train'].columns]

            datasets['X_train'] = datasets['X_train'].drop(cols_to_drop, axis=1)
            if datasets['X_valid'] is not None:
                datasets['X_valid'] = datasets['X_valid'].drop(cols_to_drop, axis=1)
            if datasets['X_holdout'] is not None:
                datasets['X_holdout'] = datasets['X_holdout'].drop(cols_to_drop, axis=1)
        self.cols_to_drop = cols_to_drop

        return datasets['X_train'], datasets['X_valid'], datasets['X_holdout']

    def calc_scores_(self):
        datasets = [k for k, v in [v['scores'] for k, v in self.folds_dict.items()][0].items() if len(v) > 0]
        self.scores = {}
        for d in datasets:
            scores = [v['scores'][d][self.eval_metric] for k, v in self.folds_dict.items()]
            print(f"CV mean score on {d}: {np.mean(scores):.4f} +/- {np.std(scores):.4f} std.")
            self.scores[d] = np.mean(scores)

    def predict(self, X_test, averaging: str = 'usual'):
        full_prediction = np.zeros((X_test.shape[0], self.oof.shape[1]))
        if self.preprocesser is not None:
            X_test = self.preprocesser.transform(X_test)
        for i in range(len(self.models)):
            X_t = X_test.copy()
            for name, transformers in self.trained_transformers.items():
                X_t = transformers[i].transform(X_t)

            if self.cols_to_drop is not None:
                cols_to_drop = [col for col in self.cols_to_drop if col in X_t.columns]
                X_t = X_t.drop(cols_to_drop, axis=1)
            y_pred = self.models[i].predict(X_t[self.folds_dict[i]['columns']]).reshape(-1, full_prediction.shape[1])

            # if case transformation changes the number of the rows
            if full_prediction.shape[0] != len(y_pred):
                full_prediction = np.zeros((y_pred.shape[0], self.oof.shape[1]))

            if averaging == 'usual':
                full_prediction += y_pred
            elif averaging == 'rank':
                full_prediction += pd.Series(y_pred).rank().values

        return full_prediction / len(self.models)

    def plot_feature_importance(self, drop_null_importance: bool = True, top_n: int = 10):

        top_feats = self.get_top_features(drop_null_importance, top_n)
        feature_importances = self.feature_importances.loc[self.feature_importances['feature'].isin(top_feats)]
        feature_importances['feature'] = feature_importances['feature'].astype(str)
        top_feats = [str(i) for i in top_feats]
        sns.barplot(data=feature_importances, x='importance', y='feature', orient='h', order=top_feats)
        plt.xticks(color='white')
        plt.yticks(color='white')
        plt.title('Feature importances')

    def get_top_features(self, drop_null_importance: bool = True, top_n: int = 10):
    
        grouped_feats = self.feature_importances.groupby(['feature'])['importance'].mean()
        if drop_null_importance:
            grouped_feats = grouped_feats[grouped_feats != 0]
        return list(grouped_feats.sort_values(ascending=False).index)[:top_n]

    def plot_metric(self):
        
        full_evals_results = pd.DataFrame()
        for model in self.models:
            evals_result = pd.DataFrame()
            for k in model.model.evals_result_.keys():
                evals_result[k] = model.model.evals_result_[k][self.eval_metric]
            evals_result = evals_result.reset_index().rename(columns={'index': 'iteration'})
            full_evals_results = full_evals_results.append(evals_result)

        full_evals_results = full_evals_results.melt(id_vars=['iteration']).rename(columns={'value': self.eval_metric,
                                                                                            'variable': 'dataset'})
        sns.lineplot(data=full_evals_results, x='iteration', y=self.eval_metric, hue='dataset')
        plt.xticks(color='white')
        plt.yticks(color='white')
        plt.title('Training progress')

# %%
def add_datepart(df:pd.DataFrame()):
    df['timestampHour'] = df['timestamp'].dt.hour
    df['timestampMonth'] = df['timestamp'].dt.month
    df['timestampMinute'] = df['timestamp'].dt.minute
    df['timestampWeek'] = df['timestamp'].dt.week
    
    return df

# %%
class MainTransformer(BaseEstimator, TransformerMixin):

    def __init__(self, convert_cyclical: bool = False, create_interactions: bool = False, n_interactions: int = 20):
        self.convert_cyclical = convert_cyclical
        self.create_interactions = create_interactions
        self.feats_for_interaction = None
        self.n_interactions = n_interactions

    def fit(self, X, y=None):

        if self.create_interactions:
            self.feats_for_interaction = [col for col in X.columns if 'sum' in col
                                          or 'mean' in col or 'max' in col or 'std' in col
                                          or 'attempt' in col]
            self.feats_for_interaction1 = np.random.choice(self.feats_for_interaction, self.n_interactions)
            self.feats_for_interaction2 = np.random.choice(self.feats_for_interaction, self.n_interactions)

        return self

    def transform(self, X, y=None):
        data = copy.deepcopy(X)
        if self.create_interactions:
            for col1 in self.feats_for_interaction1:
                for col2 in self.feats_for_interaction2:
                    data[f'{col1}_int_{col2}'] = data[col1] * data[col2]

        if self.convert_cyclical:
            data['timestampHour'] = np.sin(2 * np.pi * data['timestampHour'] / 23.0)
            data['timestampMonth'] = np.sin(2 * np.pi * data['timestampMonth'] / 23.0)
            data['timestampWeek'] = np.sin(2 * np.pi * data['timestampWeek'] / 23.0)
            data['timestampMinute'] = np.sin(2 * np.pi * data['timestampMinute'] / 23.0)
        return data

    def fit_transform(self, X, y=None, **fit_params):
        data = copy.deepcopy(X)
        self.fit(data)
        return self.transform(data)

# %%
def convert_cyclical(df):
    df['timestampHour'] = np.sin(2* np.pi *df['timestampHour']/23.0)
    df['timestampMonth'] = np.sin(2* np.pi *df['timestampMonth']/23.0)
    df['timestampWeek'] = np.sin(2* np.pi *df['timestampWeek']/23.0)
    df['timestampMinute'] = np.sin(2* np.pi *df['timestampMinute']/23.0)
    
    return df

# %%
class OptimizedRounder(object):
    def __init__(self):
        self.coef_ = 0

    def _kappa_loss(self, coef, X, y):
        X_p = pd.cut(X, [-np.inf] + list(np.sort(coef)) + [np.inf], labels = [0, 1, 2, 3])

        return -qwk(y, X_p)

    def fit(self, X, y):
        loss_partial = partial(self._kappa_loss, X=X, y=y)
        initial_coef = [0.5, 1.5, 2.5]
        self.coef_ = sp.optimize.minimize(loss_partial, initial_coef, method='nelder-mead')

    def predict(self, X, coef):
        return pd.cut(X, [-np.inf] + list(np.sort(coef)) + [np.inf], labels = [0, 1, 2, 3])

    def coefficients(self):
        return self.coef_['x']

# %%
class FeatureTransformer(BaseEstimator, TransformerMixin):

    def __init__(self, main_cat_features: list = None, num_cols: list = None):
        self.main_cat_features = main_cat_features
        self.num_cols = num_cols

    def fit(self, X, y=None):

        return self

    def transform(self, X, y=None):
        data = copy.deepcopy(X)
        return data

    def fit_transform(self, X, y=None, **fit_params):
        data = copy.deepcopy(X)
        self.fit(data)
        return self.transform(data)

# %%
def convert_dict_to_list(d):
    for i,j in d.items():
        d[i] = [v for k,v in d[i].items()]
    return d

# %%
def lgbRegression(train_df,test_df,val_df,cols_to_drop,params,splits):
    fold = GroupKFold(n_splits=splits)
    test_pred = 0
    
    if len(cols_to_drop)>0:
        train_df = train_df.drop(columns=cols_to_drop,axis=1)
        val_df = val_df.drop(columns=cols_to_drop,axis=1)
        test_df = test_df.drop(columns=cols_to_drop,axis=1)
    
    y = train_df['accuracy_group']
    val_y = val_df['accuracy_group']
    
    for i,(trn_idx, val_idx) in tqdm(enumerate(folds.split(train_df,y,train_df['installation_id']))):
        print("==========================================================")
        print(f'On fold {i}')
        
        x_train,x_val = train_df.iloc[trn_idx], train_df.iloc[val_idx]
        y_train,y_val = y.iloc[trn_idx], y.iloc[val_idx]
        
        train_set = lgb.Dataset(x_train, label = y_train)
        val_set = lgb.Dataset(x_val, label = y_val)
    
    
        clf = lgb.train(params, train_set, 10000, valid_sets = [train_set, val_set], verbose_eval=200, early_stopping_rounds=50)

        pred_val += clf.predict(x_val)
        pred_val = pred_val.reshape(len(x_val))
        
        test_pred += clf.predict(test_df)
        
    return oof/splits, test_pred/splits

# %% [markdown]
# **Reading Data**

# %%
start_time = time.time()
test = pd.read_csv('/kaggle/input/data-science-bowl-2019/test.csv')
train = pd.read_csv('/kaggle/input/data-science-bowl-2019/train.csv')
print(time.time() - start_time)
# Out:
# 86.56224131584167

# %%
train['timestamp'] = pd.to_datetime(train['timestamp'])
test['timestamp'] = pd.to_datetime(test['timestamp'])

train = add_datepart(train)
test = add_datepart(test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fddd54c6f093> in <module>
#       2 test['timestamp'] = pd.to_datetime(test['timestamp'])
#       3
# ----> 4 train = add_datepart(train)
#       5 test = add_datepart(test)
#
# NameError: name 'add_datepart' is not defined

# %%
CYCLICAL = False
if(CYCLICAL):
    train = convert_cyclical(train)
    test = convert_cyclical(test)

# %%
train_labels = pd.read_csv('/kaggle/input/data-science-bowl-2019/train_labels.csv')
specs = pd.read_csv('/kaggle/input/data-science-bowl-2019/specs.csv')
submission = pd.read_csv('/kaggle/input/data-science-bowl-2019/sample_submission.csv')

# %%
assessment_id = list(train[train['type'] == 'Assessment']['installation_id'].unique())
train = train.loc[train['installation_id'].isin(assessment_id)]

# %%
train = train.reset_index(drop=False)
train.drop(columns = ['index'],axis = 1, inplace = True)

# %%
list_of_event_code = set(train['event_code'].unique()).union(set(test['event_code'].unique()))
list_of_event_code = list(list_of_event_code)

# %%
train_game = train[(train['type'] == 'Game') | (train['type'] == 'Assessment')]
train_game = train_game.reset_index(drop=False)
train_game.drop(columns = ['index'],axis = 1, inplace = True)

train_activity = train[(train['type'] == 'Assessment') | (train['type'] == 'Activity')]
train_activity = train_activity.reset_index(drop=False)
train_activity.drop(columns = ['index'],axis = 1, inplace = True)

train_clip = train[(train['type'] == 'Assessment') | (train['type'] == 'Clip')]
train_clip = train_clip.reset_index(drop=False)
train_clip.drop(columns = ['index'],axis = 1, inplace = True)

# %% [markdown]
# **Train**

# %%
features, train_dict = get_features(train)
#features.pop()

# %%
column_mapper = {'index':'game_session'}
features = list(train_dict['901acc108f55a5a1'].keys())
for i in range(len(train_dict['901acc108f55a5a1'].keys())):
    column_mapper[i] = features[i]
column_mapper

# %%
for i,j in tqdm(train_dict.items()):
    train_dict[i] = [v for k,v in train_dict[i].items()]

# %%
train = train[(train['type'] == 'Assessment')].drop_duplicates(subset='game_session',keep = 'first').reset_index(drop=False).drop(columns=['index'],axis=1)

# %%
train_merge = pd.DataFrame().from_dict(train_dict)
train_merge = train_merge.T.reset_index(drop=False).rename(columns = column_mapper)

# %%
train = train.merge(train_merge,on='game_session',how='left')

# %%
#train.head()

# %%
int_float_cols = list(train.select_dtypes(['int64','float64']).columns)

# %%
new_train = train.copy()
#AMean
new_train = pd.merge(train,train.groupby(['installation_id']).mean(),how='left',on='installation_id',suffixes=('','_Amean'))

#deMean
new_train_data = train.groupby('installation_id')[int_float_cols].apply(lambda x:x-x.mean())
new_train_data['installation_id'] = train['installation_id']
new_train = pd.merge(new_train,new_train_data,how='left',on='installation_id',suffixes=('','_deMean'))

# %%
new_train.head()

# %%
train.shape
new_train.shape

# %%
#lag Feature
del new_train_data
count_cols = list(train.columns[train.columns.str.endswith('_count')])
count_cols.remove('event_count')
new_train_data = abs(train.groupby('installation_id',sort=False)[count_cols].diff(axis=0,periods=1))

# %%
new_train_data['installation_id'] = train['installation_id']
new_train_data['game_session'] = train['game_session']

# %%
train = pd.merge(train,new_train_data,on='game_session',how='left',suffixes=('','_lag_diff'))
train = train.drop(columns=['installation_id_lag_diff'],axis=1)

# %%
correct_attempts_mean = dict(train.groupby('installation_id')['total_correct_attempts'].mean())
train['correct_mean'] = train['installation_id'].map(correct_attempts_mean)

# %%
for c in tqdm(features):
    train[f'{c}_sum_lag'] = train[f'{c}'] + train.groupby('installation_id')[f'{c}'].shift(1)

# %%
train_mean_duration = dict(train.groupby('installation_id')['total_duration_spend_for_game'].mean())
train['mean_duration_spend'] = train['installation_id'].map(train_mean_duration)

# %%
train['clip_game'] = train['num_clip_watched'] + train['num_unique_games']

# %%
cols_for_previous_value = ['title']
for c in tqdm(cols_for_previous_value):
    train[f'{c}_prev'] = train.groupby('installation_id')[c].shift(1)

# %%
train = train.loc[train['game_session'].isin(train_labels['game_session'].unique().tolist())]

# %%
accuracy_mapper = dict(zip(train_labels['game_session'],train_labels['accuracy_group']))
train['accuracy_group'] = train['game_session'].map(accuracy_mapper)

# %%
assessment = ['mushroom','chest','bird','cauldron','cart']
train[assessment] = train.groupby('installation_id')[assessment].cumsum()
train['assessment_time_spent_cumsum'] = train.groupby('installation_id')['assessment_time_spent'].cumsum()

# %%
train['4070_count'] = train['4070_count_act'] + train['4070_count_game']
train.drop(columns=['4070_count_act','4070_count_act'],axis=1,inplace=True)

# %%
train['continious_next_assessment'] = np.zeros(train.shape[0])
train['continious_next_assessment'] = np.where(((train['num_unique_games'] == 0) & (train['num_clip_watched'] == 0)),1,0)

# %%
train.fillna(0,inplace=True)

# %%
train.head()

# %% [markdown]
# **Createing Test Labels**

# %%
test_labels = pd.DataFrame()

# %%
test_labels = test[(test['type'] == 'Assessment') & (((test['title'] == 'Bird Measurer (Assessment)') & (test['event_code'] == 4110)) | ((test['title'] != 'Bird Measurer (Assessment)') & (test['event_code'] == 4100)))]
test_labels['num_correct'] = test['event_data'].map(lambda x: 1 if(x.find('"correct":true,')>=0) else 0)
test_labels['num_incorrect'] = test['event_data'].map(lambda x: 1 if(x.find('correct":false,')>=0) else 0)

# %%
correct_data = dict(test_labels.groupby('game_session')['num_correct'].sum())
incorrect_data = dict(test_labels.groupby('game_session')['num_incorrect'].sum())

# %%
test_labels = test_labels.drop_duplicates(subset='game_session',keep='last')
test_labels['num_correct'] = test_labels['game_session'].map(correct_data)
test_labels['num_incorrect'] = test_labels['game_session'].map(incorrect_data)
test_labels['num_attempted'] = test_labels['num_correct'] + test_labels['num_incorrect']
test_labels['accuracy'] = test_labels['num_correct'] / test_labels['num_attempted']

# %%
test_labels.loc[(test_labels['type'] == 'Assessment'), 'accuracy_group'] = 0
test_labels.loc[(test_labels['accuracy'] == 1) & (test_labels['type'] == 'Assessment'), 'accuracy_group'] = 3
test_labels.loc[(test_labels['accuracy'] == 0.5) & (test_labels['type'] == 'Assessment'), 'accuracy_group'] = 2
test_labels.loc[(test_labels['accuracy'] < 0.5) & (test_labels['accuracy'] > 0) & (test_labels['num_attempted'] > 0) & (test_labels['type'] == 'Assessment'), 'accuracy_group'] = 1

# %%
#dummy_test = dummy_test[['game_session','installation_id','title','num_correct','num_incorrect','accuracy','accuracy_group']]

# %%
test_labels_first = test_labels.drop_duplicates(subset='installation_id',keep='first')
test_labels_second_last = test_labels.groupby(['installation_id']).tail(2).groupby(['installation_id']).head(1)
test_labels_third_last = test_labels.groupby(['installation_id']).tail(3).groupby(['installation_id']).head(1)
test_labels_fourth_last = test_labels.groupby(['installation_id']).tail(4).groupby(['installation_id']).head(1)
test_labels_last = test_labels.drop_duplicates(subset='installation_id',keep='last')

# %% [markdown]
# **Test**

# %%
features, test_dict = get_features(test)
#features.pop()

# %%
column_mapper = {'index':'game_session'}
features = list(test_dict['8b38fc0d2fd315dc'].keys())
for i in range(len(features)):
    column_mapper[i] = features[i]
column_mapper

# %%
for i,j in tqdm(test_dict.items()):
    test_dict[i] = [v for k,v in test_dict[i].items()]

# %%
test = test[(test['type'] == 'Assessment')].drop_duplicates(subset='game_session',keep = 'first').reset_index(drop=False).drop(columns=['index'],axis=1)

# %%
test_merge = pd.DataFrame().from_dict(test_dict)
test_merge = test_merge.T.reset_index(drop=False).rename(columns = column_mapper)

# %%
test = test.merge(test_merge,on='game_session',how='left')

# %%
int_float_cols = list(test.select_dtypes(['int64','float64']).columns)

# %%
new_test = test.copy()
#AMean
new_test = pd.merge(test,test.groupby(['installation_id']).mean(),how='left',on='installation_id',suffixes=('','_Amean'))

# %%
#deMean
new_test_data = test.groupby('installation_id')[int_float_cols].apply(lambda x:x-x.mean())
new_test_data['installation_id'] = test['installation_id']
new_test = pd.merge(new_test,new_test_data,how='left',on='installation_id',suffixes=('','_deMean'))

# %%
#lag Feature
count_cols = list(test.columns[test.columns.str.endswith('_count')])
count_cols.remove('event_count')
new_test = abs(test.groupby('installation_id')[count_cols].diff(axis=0,periods=1))

# %%
new_test['installation_id'] = test['installation_id']
new_test['game_session'] = test['game_session']

# %%
test = pd.merge(test,new_test,on='game_session',how='left',suffixes=('','_lag_diff'))
test = test.drop(columns=['installation_id_lag_diff'],axis=1)

# %%
correct_attempts_mean = dict(test.groupby('installation_id')['total_correct_attempts'].mean())
test['correct_mean'] = test['installation_id'].map(correct_attempts_mean)

# %%
for c in tqdm(features):
    test[f'{c}_sum_lag'] = test[f'{c}'] + test.groupby('installation_id')[f'{c}'].shift(1)

# %%
cols_for_previous_value = ['title']
for c in tqdm(cols_for_previous_value):
    test[f'{c}_prev'] = test.groupby('installation_id')[c].shift(1)

# %%
test_mean_duration = dict(test.groupby('installation_id')['total_duration_spend_for_game'].mean())
test['mean_duration_spend'] = test['installation_id'].map(test_mean_duration)

# %%
#test['title_prev'] = test.groupby('installation_id')['title'].shift(1)
test['clip_game'] = test['num_clip_watched'] + test['num_unique_games']

# %%
assessment = ['mushroom','chest','bird','cauldron','cart']
test[assessment] = test.groupby('installation_id')[assessment].cumsum()
test['assessment_time_spent_cumsum'] = test.groupby('installation_id')['assessment_time_spent'].cumsum()

# %%
test['4070_count'] = test['4070_count_act'] + test['4070_count_game']
test.drop(columns=['4070_count_act','4070_count_act'],axis=1,inplace=True)

# %%
test['continious_next_assessment'] = np.zeros(test.shape[0])
test['continious_next_assessment'] = np.where(((test['num_unique_games'] == 0) & (test['num_clip_watched'] == 0)),1,0)

# %%
test.fillna(0,inplace=True)

# %%
list_of_user_activities = list(set(train['title'].value_counts().index).union(set(test['title'].value_counts().index)))
activities_map = dict(zip(list_of_user_activities, np.arange(len(list_of_user_activities))))

train['title'] = train['title'].map(activities_map)
train['title_prev'] = train['title_prev'].map(activities_map)
train_labels['title'] = train_labels['title'].map(activities_map)

test['title'] = test['title'].map(activities_map)
test['title_prev'] = test['title_prev'].map(activities_map)

# %%
world = list(set(train['world'].unique().tolist()).union(set(test['world'].unique().tolist())))
world = dict(zip(world,np.arange(len(world))))

train['world'] = train['world'].map(world)
test['world'] = test['world'].map(world)

# %%
cat_features = ['title','title_prev']

# %%
train[cat_features] = train[cat_features].astype('category')
test[cat_features] = test[cat_features].astype('category')

# %% [markdown]
# **Validation Part**

# %%
dummy_test_first = test.drop_duplicates(subset='installation_id',keep='first')
dummy_test_second_last = test.groupby(['installation_id']).tail(2).groupby(['installation_id']).head(1)
dummy_test_third_last = test.groupby(['installation_id']).tail(3).groupby(['installation_id']).head(1)
dummy_test_fourth_last = test.groupby(['installation_id']).tail(4).groupby(['installation_id']).head(1)
dummy_test_last = test.drop_duplicates(subset='installation_id',keep='last')

# %% [markdown]
# **Preprocessing**

# %%
cols_to_drop_1 = []
cols_to_drop_1.append(list(train.columns[train.columns.str.startswith('event')]))
cols_to_drop_1.append(list(train.columns[train.columns.str.startswith('game_time')]))
cols_to_drop_1 = list(chain.from_iterable(cols_to_drop_1))
cols_to_drop_1

# %%
print(train['game_session'].nunique())
print(train_labels['game_session'].nunique())

# %%
#instal_id_mapper = list(set(train['installation_id'].unique().tolist()).union(set(test['installation_id'].unique().tolist())))
#instal_id_mapper = dict(zip(instal_id_mapper,np.arange(len(instal_id_mapper))))

#for df in tqdm([train,test]):
#    df['installation_id'] = df['installation_id'].map(instal_id_mapper)

# %%
cols_to_drop = ['game_session', 'installation_id', 'timestamp', 'accuracy_group','event_id','event_data','event_count',
                'event_code','game_time','type']
cols_to_drop = list(set(cols_to_drop).union(set(cols_to_drop_1)))
n_fold = 5
folds = GroupKFold(n_splits=n_fold)
y = train['accuracy_group']

# %%
cols_to_drop

# %%
seed_everything(np.random.randint(1,1000))

# %%
plt.figure(figsize=(40,30))
plt.xticks(color='white')
plt.yticks(color='white')
cols = train.select_dtypes(include=['int64','float64']).columns
corr = train[cols].corr(method = 'pearson')
corr = corr*100
sns.heatmap(corr,annot=True)

# %% [markdown]
# **Training Part**

# %% [markdown]
# 1) Using Object Oriented LightGBM Approah with Nelder-Mead Local Minima Optimizations

# %%
params = {  'n_estimators':200,
            'boosting_type': 'gbdt',
            'objective': 'regression',
             'metric': 'rmse',
            'subsample': 0.75,
            'subsample_freq': 1,
            'feature_fraction': 0.9,
            'verbose_eval':50,
            'verbose': 100,
            'early_stopping_rounds': 100, 
            'eval_metric': 'cappa'
            }

# %%
t

# %%
def LGB_bayesian(max_depth,
                 lambda_l1,
                 lambda_l2,
                 bagging_fraction,
                 bagging_freq,
                 colsample_bytree,
                 learning_rate):
    
    params = {
        'boosting_type': 'gbdt',
        'metric': 'rmse',
        'objective': 'regression',
        'eval_metric': 'cappa',
        'n_jobs': -1,
        'seed': 42,
        'early_stopping_rounds': 100,
        'n_estimators': 2000,
        'learning_rate': learning_rate,
        'max_depth': int(max_depth),
        'lambda_l1': lambda_l1,
        'lambda_l2': lambda_l2,
        'bagging_fraction': bagging_fraction,
        'bagging_freq': int(bagging_freq),
        'colsample_bytree': colsample_bytree,
        'verbose': 0
    }
    mt = MainTransformer()
    ft = FeatureTransformer()
    transformers = {'ft': ft}
    model = RegressorModel(model_wrapper=LGBWrapper_regr())
    model.fit(X=train, 
              y=y, 
              folds=folds, 
              params=params, 
              preprocesser=mt, 
              transformers=transformers,
              eval_metric='cappa', 
              cols_to_drop=cols_to_drop,
              plot=False)
    
    return model.scores['valid']

# %%
bounds_LGB = {
    'max_depth': (8, 16),
    'lambda_l1': (0, 10),
    'lambda_l2': (0, 10),
    'bagging_fraction': (0.2, 1),
    'bagging_freq': (1, 10),
    'colsample_bytree': (0.2, 1),
    'learning_rate': (0.005, 0.3)
}

LGB_BO = BayesianOptimization(LGB_bayesian, bounds_LGB, random_state=1029)

init_points = 10
n_iter = 10

# %%
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    LGB_BO.maximize(init_points=init_points, n_iter=n_iter, acq='ucb', xi=0.0, alpha=1e-6)

# %%
params = {  'n_estimators':200,
            'boosting_type': 'gbdt',
            'objective': 'regression',
             'metric': 'rmse',
            'subsample': 0.75,
            'subsample_freq': 1,
            'learning_rate': LGB_BO.max['params']['learning_rate'],
            'max_depth': int(LGB_BO.max['params']['max_depth']),
            'lambda_l1': LGB_BO.max['params']['lambda_l1'],
            'lambda_l2': LGB_BO.max['params']['lambda_l2'],
            'bagging_fraction': LGB_BO.max['params']['bagging_fraction'],
            'bagging_freq': int(LGB_BO.max['params']['bagging_freq']),
            'colsample_bytree': LGB_BO.max['params']['colsample_bytree'],
            'feature_fraction': 0.9,
            'verbose_eval':50,
            'verbose': 100,
            'early_stopping_rounds': 100, 
            'eval_metric': 'cappa'
            }

# %%
mt = MainTransformer()
ft = FeatureTransformer()
transformers = {'ft': ft}
regressor_model1 = RegressorModel(model_wrapper=LGBWrapper_regr())
regressor_model1.fit(X=train, y=y, folds=folds,params=params, preprocesser=mt, transformers=transformers,
                    eval_metric='cappa', cols_to_drop=cols_to_drop)

# %%
feature_importance = regressor_model1.feature_importances
feature_importance_columns = list(set(feature_importance['feature']))

# %%
pr1 = regressor_model1.predict(train)
optR = OptimizedRounder()
optR.fit(pr1.reshape(-1,), y)
coefficients = optR.coefficients()
coefficients = list(coefficients)
print(coefficients)

# %%
opt_preds = optR.predict(pr1.reshape(-1, ), coefficients)
qwk(y, opt_preds)

# %%
val_y = test_labels_first['accuracy_group']
val_pred = regressor_model1.predict(dummy_test_first)
val_opt = optR.predict(val_pred.reshape(-1,),coefficients)
qwk(val_y,val_opt)

# %%
val_y = test_labels_second_last['accuracy_group']
val_pred = regressor_model1.predict(dummy_test_second_last)
val_opt = optR.predict(val_pred.reshape(-1,),coefficients)
qwk(val_y,val_opt)

# %%
val_y = test_labels_third_last['accuracy_group']
val_pred = regressor_model1.predict(dummy_test_third_last)
val_opt = optR.predict(val_pred.reshape(-1,),coefficients)
qwk(val_y,val_opt)

# %%
val_y = test_labels_fourth_last['accuracy_group']
val_pred = regressor_model1.predict(dummy_test_fourth_last)
val_opt = optR.predict(val_pred.reshape(-1,),coefficients)
qwk(val_y,val_opt)

# %%
val_y = test_labels_last['accuracy_group']
val_pred = regressor_model1.predict(dummy_test_last)
val_opt = optR.predict(val_pred.reshape(-1,),coefficients)
qwk(val_y,val_opt)

# %%
pr1 = regressor_model1.predict(test)
pr1[pr1 <= coefficients[0]] = 0
pr1[np.where(np.logical_and(pr1 > coefficients[0], pr1 <= coefficients[1]))] = 1
pr1[np.where(np.logical_and(pr1 > coefficients[1], pr1 <= coefficients[2]))] = 2
pr1[pr1 > coefficients[2]] = 3

# %% [markdown]
# **Training using functional LGBM Approach**

# %%
def lgbRegression(train_df,test_df,val_df,cols_to_drop,params,splits):
    fold = GroupKFold(n_splits=splits)
    test_pred = 0
    val_pred = 0
    oof_pred = 0
    
    y = train_df['accuracy_group']
    val_y = val_df['accuracy_group']
    
    if len(cols_to_drop)>0:
        train_df = train_df.drop(columns=cols_to_drop,axis=1)
        val_df = val_df.drop(columns=cols_to_drop,axis=1)
        test_df = test_df.drop(columns=cols_to_drop,axis=1)
    
    for i,(trn_idx, val_idx) in tqdm(enumerate(folds.split(train_df,y,train_df['installation_id']))):
        print("==========================================================")
        print(f'On fold {i}')
        
        x_train,x_val = x.iloc[trn_idx], x.iloc[val_idx]
        y_train,y_val = y.iloc[trn_idx], y.iloc[val_idx]
        
        train_set = lgb.Dataset(x_train, label = y_train)
        val_set = lgb.Dataset(x_val, label = y_val)
    
    
        clf = lgb.train(params, train_set, 10000, valid_sets = [train_set, val_set], verbose_eval=200, early_stopping_rounds=50)

        val_pred += clf.predict(x_val)
        oof = clf.predict(x_val)
        test_pred += clf.predict(test_df)
        
        del x_train,x_val,y_train,y_val,train_set,val_set
        gc.collect()
        
    return oof/splits, val_pred/splits, test_pred/splits

# %% [markdown]
# **Submitting the Prediction**

# %%
test['accuracy_group'] = pr1
new_test = test.drop_duplicates(subset='installation_id',keep='last').reset_index(drop=False).drop(columns=['index'],axis=1)
test_prediction_dict = dict(zip(new_test['installation_id'],new_test['accuracy_group']))

# %%
submission['accuracy_group'] = submission['installation_id'].map(test_prediction_dict)
submission['accuracy_group'] = submission['accuracy_group'].astype(int)
submission.head()

# %%
submission['accuracy_group'].value_counts()

# %%
submission.to_csv('submission.csv',index=False)

# %% [markdown]
# **Garbage**

# %%
def new():
    cols = train.columns.tolist()
    cols.remove('installation_id')
    for i ,data in train.groupby('installation_id',sort=False):
        new_data = data[cols]
        new_data['installation_id'] = i
        break
    return new_data.head()

# %%
def get_features(df:pd.DataFrame(),which):
    
    new_df_list_values = []
    event_code_count_dict = {eve : 0 for eve in list_of_event_code}
    new_df_dict = {}
        
    df = df.reset_index(drop= False)
    df.drop(columns=['index'],axis=1,inplace=True)
    
    for i,data in tqdm(df.groupby('installation_id',sort=False)):
        print(i)
        new_data = data[df.columns.tolist()]
        new_data['installation_id'] = i
        
        new_data = new_data.reset_index(drop= False)
        new_data.drop(columns=['index'],axis=1,inplace=True)
        
        a1 = new_data[new_data['type'] == 'Assessment'].drop_duplicates(subset = 'game_session',keep = 'first').index.tolist()
        a2 = new_data[new_data['type'] == 'Assessment'].drop_duplicates(subset = 'game_session',keep = 'last').index.tolist()

        a = []
        a.append(0)
        print(a2)
        for i in range(len(a2)):
            a.append(a2[i])
            a.append(a2[i]+1)
        a.pop(len(a)-1)
        print(a)

        for i in range(0,len(a),2):
            print(a[i] , 'to' , a[i+1])
            new_df = data.iloc[a[i]:a[i+1]+1,:]
            g_session = new_df[new_df['type'] == 'Assessment']['game_session'].unique()[-1]
            print(g_session)
            new_df_dict[g_session] = {}
            new_df_dict[g_session]['num_game_session'] = new_df['game_session'].nunique()
            new_df_dict[g_session]['num_event_id'] = new_df['event_id'].nunique()
            new_df_dict[g_session]['num_actions_before_assessment'] = len(new_df['event_code'])
            new_df_dict[g_session][f'num_unique_{which}'] = new_df[new_df['type'] == which]['title'].nunique()
            if(which == 'Game'):
                new_df_dict[g_session]['game_attempts'] = new_df[new_df['event_code'] == 4020]['event_code'].count()
                new_df_dict[g_session]['mean_game_time'] = new_df[new_df['type'] == 'Game']['game_time'].mean()
                new_df_dict[g_session]['max_game_time'] = new_df[new_df['type'] == 'Game']['game_time'].max()
                new_df_dict[g_session]['min_game_time'] = new_df[new_df['type'] == 'Game']['game_time'].min()
                new_df_dict[g_session]['std_game_time'] = new_df[new_df['type'] == 'Game']['game_time'].std()
                new_df['gaming_accuracy'] = new_df[(new_df['type'] == 'Game') & (new_df['event_code'] == 4020)]['event_data'].map(lambda x:1 if(str(x).find('"correct":true')) else 0)
                new_df['gaming_accuracy'].fillna(0,inplace=True)
                new_df_dict[g_session]['gaming_accuracy'] = new_df['gaming_accuracy'].sum()/new_df_dict[g_session]['game_attempts']
            elif(which == 'Activity'):
                new_df_dict[g_session]['Activity actions'] = new_df[new_df['type'] == 'Activity']['event_id'].count()

            for k,v in event_code_count_dict.items():
                new_df_dict[g_session][k] = v

            for i in event_code_count_dict.keys():
                 new_df_dict[g_session][i] = new_df[new_df['event_code'] == i]['event_code'].count()
            #break
    return new_df_dict

# %%
def get_features(df:pd.DataFrame(),which):
    
    new_df_list_values = []
    event_code_count_dict = {}
    new_df_dict = {}
    
    for i in train['event_code'].unique().tolist():
        event_code_count_dict[i] = 0
        
    df = df.reset_index(drop= False)
    df.drop(columns=['index'],axis=1,inplace=True)
    
    a1 = df[df['type'] == 'Assessment'].drop_duplicates(subset = 'game_session',keep = 'first').index.tolist()
    a2 = df[df['type'] == 'Assessment'].drop_duplicates(subset = 'game_session',keep = 'last').index.tolist()
    
    a = []
    a.append(0)
    for i in range(len(a2)):
        a.append(a2[i])
        a.append(a2[i]+1)
    a.pop(len(a)-1)
    
    for i in tqdm(range(len(a))):
        new_df = df.iloc[a[i]:a[i+1],:]
        ids  = new_df['installation_id'].unique().tolist()[-1]
        new_df_dict[ids] = {}
        new_df_dict['num_game_session'] = new_df['game_session'].nunique()
        new_df_dict['num_event_id'] = new_df['event_id'].nunique()
        new_df_dict['num_actions_before_assessment'] = len(new_df['event_code'])
        new_df_dict[f'num_unique_{which}'] = new_df[new_df['type'] == which]['title'].nunique()
        if(which == 'Game'):
            new_df_dict['game_attempts'] = new_df[new_df['event_code'] == 4020]['event_code'].count()
            new_df_dict['mean_game_time'] = new_df[new_df['type'] == 'Game']['game_time'].mean()
            new_df_dict['max_game_time'] = new_df[new_df['type'] == 'Game']['game_time'].max()
            new_df_dict['min_game_time'] = new_df[new_df['type'] == 'Game']['game_time'].min()
            new_df_dict['std_game_time'] = new_df[new_df['type'] == 'Game']['game_time'].std()
            new_df['gaming_accuracy'] = new_df[(new_df['type'] == 'Game') & (new_df['event_code'] == 4020)]['event_data'].map(lambda x:1 if(str(x).find('"correct":true')) else 0)
            new_df['gaming_accuracy'].fillna(0,inplace=True)
            new_df_dict['gaming_accuracy'] = new_df['gaming_accuracy'].sum()/new_df_dict['game_attempts']
            #new_df['time_gap_before_assessment'] = new_df['']
        elif(which == 'Activity'):
            new_df_dict['Activity actions'] = new_df[new_df['type'] == 'Activity']['event_id'].count()
        
        event_code_count_dict.update(new_df_dict)
        break
    print(event_code_count_dict)

# %%
def get_features(df:pd.DataFrame(),which):
    
    new_df_list_values = []
    event_code_count_dict = {eve : 0 for eve in list_of_event_code}
    new_df_dict = {}
        
    df = df.reset_index(drop= False)
    df.drop(columns=['index'],axis=1,inplace=True)
    
    a1 = df[df['type'] == 'Assessment'].drop_duplicates(subset = 'game_session',keep = 'first').index.tolist()
    a2 = df[df['type'] == 'Assessment'].drop_duplicates(subset = 'game_session',keep = 'last').index.tolist()
    
    a = []
    a.append(0)
    for i in range(len(a2)):
        a.append(a2[i])
        a.append(a2[i]+1)
    a.pop(len(a)-1)
    
    for i in tqdm(range(10)):
        new_df = df.iloc[a[i]:a[i+1],:]
        ids  = new_df['installation_id'].unique().tolist()[-1]
        g_session = new_df[new_df['type'] == 'Assessment']['game_session'].unique()[-1]
        print(ids,g_session)
        new_df_dict[ids] = {}
        new_df_dict[ids][g_session] = {}
        new_df_dict[ids][g_session]['num_game_session'] = new_df['game_session'].nunique()
        new_df_dict[ids][g_session]['num_event_id'] = new_df['event_id'].nunique()
        new_df_dict[ids][g_session]['num_actions_before_assessment'] = len(new_df['event_code'])
        new_df_dict[ids][g_session][f'num_unique_{which}'] = new_df[new_df['type'] == which]['title'].nunique()
        if(which == 'Game'):
            new_df_dict[ids][g_session]['game_attempts'] = new_df[new_df['event_code'] == 4020]['event_code'].count()
            new_df_dict[ids][g_session]['mean_game_time'] = new_df[new_df['type'] == 'Game']['game_time'].mean()
            new_df_dict[ids][g_session]['max_game_time'] = new_df[new_df['type'] == 'Game']['game_time'].max()
            new_df_dict[ids][g_session]['min_game_time'] = new_df[new_df['type'] == 'Game']['game_time'].min()
            new_df_dict[ids][g_session]['std_game_time'] = new_df[new_df['type'] == 'Game']['game_time'].std()
            new_df['gaming_accuracy'] = new_df[(new_df['type'] == 'Game') & (new_df['event_code'] == 4020)]['event_data'].map(lambda x:1 if(str(x).find('"correct":true')) else 0)
            new_df['gaming_accuracy'].fillna(0,inplace=True)
            new_df_dict[ids][g_session]['gaming_accuracy'] = new_df['gaming_accuracy'].sum()/new_df_dict[ids][g_session]['game_attempts']
        elif(which == 'Activity'):
            new_df_dict[ids][g_session]['Activity actions'] = new_df[new_df['type'] == 'Activity']['event_id'].count()
        
        for k,v in event_code_count_dict.items():
            new_df_dict[ids][g_session][k] = v
        
        for i in event_code_count_dict.keys():
             new_df_dict[ids][g_session][i] = new_df[new_df['event_code'] == i]['event_code'].count()
        break
    return new_df_dict

# %%
def g5():
    train_column_values = {}
    for i in tqdm(train['installation_id'].unique().tolist()):
        df = train[(train['installation_id'] == i) & ((train['type'] == 'Game') | (train['type'] == 'Assessment'))]
        column_values_instance = get_features(df,'Game')
        train_column_values.update(column_values_instance)
    train_column_values

# %%
def g4():
    per_install_id_features = {}
    event_code_count_per_id = {}
    for i,data in tqdm(train.groupby('installation_id',sort = False)):
        new_data = data[data.columns.tolist()]
        per_install_id_features[i] = {}
        for j in ['Game','Activity','Clip']:
            per_install_id_features[i][f'num_{j}'] = new_data[new_data['type'] == j]['title'].nunique()
        per_install_id_features[i]['total_num_actions'] = new_data[(new_data['type'] == 'Game') | (new_data['type'] == 'Activity') | (new_data['type'] == 'Clip')]['event_id'].count()
        per_install_id_features[i]['total_game_attempts'] = new_data[(new_data['type'] == 'Game') & (new_data['event_code'] == 4020)]['event_code'].count()
        new_data['correct_attempts'] = new_data[(new_data['type'] == 'Game') & (new_data['event_code'] == 4020)]['event_data'].map(lambda x:1 if(str(x).find('"correct":true'))>=0 else 0)
        per_install_id_features[i]['total_correct_game_attempts'] = new_data['correct_attempts'].sum()
        per_install_id_features[i]['total_accuracy'] = per_install_id_features[i]['total_correct_game_attempts']/per_install_id_features[i]['total_game_attempts'] if per_install_id_features[i]['total_game_attempts'] >0 else 0

    per_install_id_features

# %%
def g3():
    clip_features = ['num_clip_watched']
    game_features = ['num_unique_games','total_game_actions','total_duration_spend_for_game','total_game_attempts','total_correct_attempts','last_game_played_accuracy','gaming_accuracy']
    activity_features = []
    total_data = {}

    for i,install_id in tqdm(test.groupby('installation_id',sort=False)):

        clip_data = {eve : 0 for eve in clip_features}
        game_data = {eve : 0 for eve in game_features}
        activity_data = {}
        event_code_count = {eve : 0 for eve in list_of_event_code}

        for j,session in install_id.groupby('game_session',sort=False):

            session_type = session['type'].iloc[0]
            session_title = session['title'].iloc[0]

            if((session_type == 'Clip')):
                clip_data['num_clip_watched'] += 1

            elif(session_type == 'Game'):
                game_data['num_unique_games'] += 1
                game_data['total_game_actions'] += session['event_code'].count()
                game_data['total_duration_spend_for_game'] += int(session['game_time'].iloc[-1]/1000)
                game_data['total_game_attempts'] += session[session['event_code'] == 4020]['event_code'].count()
                game_data['total_correct_attempts'] += session[session['event_code'] == 4020]['event_data'].map(lambda x:1 if(str(x).find('"correct":true') >= 0) else 0).sum()
                game_data['gaming_accuracy'] += np.round((game_data['total_correct_attempts']/game_data['total_game_attempts']),3)
                game_data['last_game_played_accuracy'] = np.round(game_data['total_correct_attempts'] / game_data['total_game_attempts'],3) if(game_data['total_game_attempts']>0) else 0
            elif(session_type == 'Activity'):
                pass
            elif(session_type == 'Assessment'):
                #game_preprocessing


                #Activity preprocessing


                #Clip preprocessing



                total_data[j] = {}
                total_data[j].update(clip_data)
                total_data[j].update(activity_data)
                total_data[j].update(game_data)

                clip_data = {eve : 0 for eve in clip_features}
                game_data = {eve : 0 for eve in game_features}
                activity_data = {}
        #break   

    total_data

# %%
def g2():
    train = train[(train['type'] == 'Assessment') & (((train['event_code'] == 4100) & (train['title'] != 'Bird Measurer (Assessment)')) | ((train['event_code'] == 4110) & (train['title'] == 'Bird Measurer (Assessment)')))]

    session_count = train['game_session'].value_counts().to_dict()
    train['assessment_attempt_count'] = train['game_session'].map(session_count)

    train['contains_true_assessment'] = train['event_data'].map(lambda x: True if (x.find('"correct":true')>=0) else False)

    change_value = {
        True : 1,
        False : 0
    }
    train['contains_true_assessment'] = train['contains_true_assessment'].map(change_value)

    correct_attempt = dict(train.groupby('game_session',sort=False)['contains_true_assessment'].sum())
    train['contains_true_assessment_count'] = train['game_session'].map(correct_attempt)

    for c in ['contains_true_assessment']:
        train.pop(c)

    train['accumulated_accuracy'] = np.where((train['contains_true_assessment_count'] == 0),0,(train['contains_true_assessment_count']/train['assessment_attempt_count']))

    train.loc[(train['type'] == 'Assessment'), 'accuracy_group'] = 0
    train.loc[(train['accumulated_accuracy'] == 1) & (train['type'] == 'Assessment'), 'accuracy_group'] = 3
    train.loc[(train['accumulated_accuracy'] == 0.5) & (train['type'] == 'Assessment'), 'accuracy_group'] = 2
    train.loc[(train['accumulated_accuracy'] < 0.5) & (train['accumulated_accuracy'] > 0) & (train['assessment_attempt_count'] > 0) & (train['type'] == 'Assessment'), 'accuracy_group'] = 1

    train.rename(columns = {'contains_true_assessment_count': 'num_correct',
                            'accumulated_accuracy':'accuracy',
                            'assessment_attempt_count': 'total_attempt'},inplace=True)
    train = train.drop_duplicates(subset = 'game_session',keep = 'last')
    train = train.reset_index(drop=False)
    train.drop(columns = ['index'],axis = 1, inplace = True)
    train.shape

# %%
def g1():
    test =  test[(test['type'] == 'Assessment') &  ((test['event_count'] == 1) | ((test['event_code'] == 4100) & (test['title'] != 'Bird Measurer (Assessment)')) | ((test['event_code'] == 4110) & (test['title'] == 'Bird Measurer (Assessment)')))]
    session_count = test['game_session'].value_counts().to_dict()
    test['assessment_attempt_count'] = test['game_session'].map(session_count)

    test['contains_true_assessment'] = test['event_data'].map(lambda x: True if (x.find('"correct":true')>=0) else False)

    change_value = {
        True : 1,
        False : 0
    }
    test['contains_true_assessment'] = test['contains_true_assessment'].map(change_value)

    correct_attempt = dict(test.groupby('game_session',sort=False)['contains_true_assessment'].sum())
    test['contains_true_assessment_count'] = test['game_session'].map(correct_attempt)


    for c in ['contains_true_assessment']:
        test.pop(c)

    test['accumulated_accuracy'] = np.where((test['contains_true_assessment_count'] == 0),0,(test['contains_true_assessment_count']/test['assessment_attempt_count']))

    test.loc[(test['type'] == 'Assessment'), 'accuracy_group'] = 0
    test.loc[(test['accumulated_accuracy'] == 1) & (test['type'] == 'Assessment'), 'accuracy_group'] = 3
    test.loc[(test['accumulated_accuracy'] == 0.5) & (test['type'] == 'Assessment'), 'accuracy_group'] = 2
    test.loc[(test['accumulated_accuracy'] < 0.5) & (test['accumulated_accuracy'] > 0) & (test['assessment_attempt_count'] > 0) & (test['type'] == 'Assessment'), 'accuracy_group'] = 1

    test.rename(columns = {'contains_true_assessment_count': 'num_correct',
                            'accumulated_accuracy':'accuracy',
                            'assessment_attempt_count': 'total_attempt'},inplace=True)

    test = test.drop_duplicates(subset = 'game_session',keep = 'last')
    test = test.reset_index(drop=False)
    test.drop(columns = ['index'],axis = 1, inplace = True)
    test.shape

# %%
def g8():
    oof = np.zeros(len(x))
    NFOLDS = 5
    folds = KFold(n_splits=NFOLDS, shuffle=True, random_state=2019)


    for fold, (trn_idx, test_idx) in enumerate(folds.split(x, y)):

        print(f'Training on fold {fold+1}')
        clf = make_classifier()
        clf.fit(x.loc[trn_idx], y.loc[trn_idx], eval_set=(x.loc[test_idx], y.loc[test_idx]),
                              use_best_model=True, verbose=500)

        oof[test_idx] = clf.predict(x.loc[test_idx]).reshape(len(test_idx))
        print('OOF QWK:', qwk(y, oof))

    print('-' * 30)
    print('OOF QWK:', qwk(y, oof))
    print('-' * 30)

# %%
def plot_feature_importance(self, drop_null_importance: bool = True, top_n: int = 10):

        top_feats = self.get_top_features(drop_null_importance, top_n)
        feature_importances = self.feature_importances.loc[self.feature_importances['feature'].isin(top_feats)]
        feature_importances['feature'] = feature_importances['feature'].astype(str)
        top_feats = [str(i) for i in top_feats]
        sns.barplot(data=feature_importances, x='importance', y='feature', orient='h', order=top_feats)
        plt.title('Feature importances')

    def get_top_features(self, drop_null_importance: bool = True, top_n: int = 10):
    
        grouped_feats = self.feature_importances.groupby(['feature'])['importance'].mean()
        if drop_null_importance:
            grouped_feats = grouped_feats[grouped_feats != 0]
        return list(grouped_feats.sort_values(ascending=False).index)[:top_n]

    def plot_metric(self):
        
        full_evals_results = pd.DataFrame()
        for model in self.models:
            evals_result = pd.DataFrame()
            for k in model.model.evals_result_.keys():
                evals_result[k] = model.model.evals_result_[k][self.eval_metric]
            evals_result = evals_result.reset_index().rename(columns={'index': 'iteration'})
            full_evals_results = full_evals_results.append(evals_result)

        full_evals_results = full_evals_results.melt(id_vars=['iteration']).rename(columns={'value': self.eval_metric,
                                                                                            'variable': 'dataset'})
        sns.lineplot(data=full_evals_results, x='iteration', y=self.eval_metric, hue='dataset')
        plt.title('Training progress')

# %%
def get_features(df):
    total_features = []
    clip_features = ['num_clip_watched']
    game_features = ['num_unique_games','total_game_actions','total_duration_spend_for_game','total_game_attempts',
                     'total_correct_attempts','last_game_played_accuracy','gaming_accuracy','3010_count_game','3020_count_game','4030_count_game',
                     '3110_count_game','4035_count_game','4025_count_game','3120_count_game','2010_count_game','4070_count_game','chow_time']
    #activity_features = ['total_duration_spend_for_activity','4070_count_activity','3010_count_activity','3020_count_activity','4030_count_activity','3110_count_activity',
    #                     '4035_count_activity','4025_count_activity','3120_count_activity','2010_count_activity']
    total_data = {}
    total_features = clip_features + game_features# + activity_features
    for i,install_id in tqdm(df.groupby('installation_id',sort=False)):

        clip_data = {eve : 0 for eve in clip_features}
        game_data = {eve : 0 for eve in game_features}
        activity_data = {eve : 0 for eve in activity_features}
        event_code_count = {f'{eve}_count' : 0 for eve in list_of_event_code}

        for j,session in install_id.groupby('game_session',sort=False):

            session_type = session['type'].iloc[0]
            session_title = session['title'].iloc[0]

            if((session_type == 'Clip')):
                clip_data['num_clip_watched'] += 1
                
            elif(session_type == 'Game'):
                game_data['num_unique_games'] += 1
                game_data['total_game_actions'] += session['event_code'].count()
                game_data['total_duration_spend_for_game'] += int(session['game_time'].iloc[-1]/1000)
                game_data['total_game_attempts'] += session[session['event_code'] == 4020]['event_code'].count()
                game_data['total_correct_attempts'] += session[session['event_code'] == 4020]['event_data'].map(lambda x:1 if(str(x).find('"correct":true') >= 0) else 0).sum()
                game_data['gaming_accuracy'] += round((game_data['total_correct_attempts']/game_data['total_game_attempts']),3) if(game_data['total_game_attempts']>0) else 0
                game_data['last_game_played_accuracy'] = round(game_data['total_correct_attempts'] / game_data['total_game_attempts'],3) if(game_data['total_game_attempts']>0) else 0
                game_data['chow_time'] += session[session['title'] == 'Chow Time']['title'].count()
                game_data['4070_count_game'] += session[session['event_code']==4070]['event_code'].count()
                game_data['3010_count_game'] += session[session['event_code']==3010]['event_code'].count()
                game_data['3020_count_game'] += session[session['event_code']==3020]['event_code'].count()
                game_data['4030_count_game'] += session[session['event_code'] == 4030]['event_code'].count()
                game_data['3110_count_game'] += session[session['event_code'] == 3110]['event_code'].count()
                game_data['4035_count_game'] += session[session['event_code'] == 4035]['event_code'].count()
                game_data['4025_count_game'] += session[session['event_code'] == 4025]['event_code'].count()
                game_data['3120_count_game'] += session[session['event_code'] == 3120]['event_code'].count()
                game_data['2010_count_game'] += session[session['event_code'] == 2010]['event_code'].count()
                #for i in list(set(train['event_code'].unique()).union(set(test['event_code'].unique()))):
                    #event_code_count[f'{i}_count'] += session[session['event_code'] == i].count()
            elif(session_type == 'Activity'):
                pass
            elif(session_type == 'Assessment'):
                #game_preprocessing


                #Activity preprocessing


                #Clip preprocessing



                total_data[j] = {}
                total_data[j].update(clip_data)
               #total_data[j].update(activity_data)
                total_data[j].update(game_data)
                #total_data[j].update(event_code_count)

                clip_data = {eve : 0 for eve in clip_features}
                game_data = {eve : 0 for eve in game_features}
                #activity_data = {}
    return total_features,total_data

# %%
# %%capture

# %%
def get_data(user_sample, test_set=False):
    last_activity = 0
    print(f'last_activity : {last_activity}')
    user_activities_count = {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
    print(f'user_activities_count : {user_activities_count}')
    time_spent_each_act = {actv: 0 for actv in list_of_user_activities}
    print(f'time_spent_each_act : {time_spent_each_act}')
    event_code_count = {eve: 0 for eve in list_of_event_code}
    print(f'event_code_count : {event_code_count}')
    last_session_time_sec = 0
    print(f'last_session_time_sec : {last_session_time_sec}')
    
    accuracy_groups = {0:0, 1:0, 2:0, 3:0}
    print(f'accuracy_groups : {accuracy_groups}')
    all_assessments = []
    print(f'all_assessments : {all_assessments}')
    accumulated_accuracy_group = 0
    print(f'accumulated_accuracy_group : {accumulated_accuracy_group}')
    accumulated_accuracy=0
    print(f'accumulated_accuracy : {accumulated_accuracy}')
    accumulated_correct_attempts = 0 
    print(f'accumulated_correct_attempts : {accumulated_correct_attempts}')
    accumulated_uncorrect_attempts = 0 
    print(f'accumulated_uncorrect_attempts : {accumulated_uncorrect_attempts}')
    accumulated_actions = 0
    print(f'accumulated_actions : {accumulated_actions}')
    counter = 0
    print(f'counter : {counter}')
    time_first_activity = float(user_sample['timestamp'].values[0])
    print(f'time_first_activity : {time_first_activity}')
    durations = []
    print(f'durations : {durations}')
    
    for i, session in user_sample.groupby('game_session', sort=False):
        print(f'i : {i}')
        session_type = session['type'].iloc[0]
        print(f'session_type : {session_type}')
        session_title = session['title'].iloc[0]
        print(f'session_title : {session_title}')
        session_title_text = activities_labels[session_title] #from Andrew
        print(f'session_title_text : {session_title_text}')
        
        if session_type != 'Assessment':
            time_spent = int(session['game_time'].iloc[-1] / 1000)
            print(f'time_spent : {time_spent}')
            time_spent_each_act[activities_labels[session_title]] += time_spent
            print(f'time_spent_each_act[activities_labels[session_title]] : {time_spent_each_act[activities_labels[session_title]]}')
        
        if (session_type == 'Assessment') & (test_set or len(session)>1):
            all_attempts = session.query(f'event_code == {win_code[session_title]}')
            print(f'all_attempts : {all_attempts}')
            true_attempts = all_attempts['event_data'].str.contains('true').sum()
            print(f'true_attempts : {true_attempts}')
            false_attempts = all_attempts['event_data'].str.contains('false').sum()
            print(f'false_attempts : {false_attempts}')
            features = user_activities_count.copy()
            print(f'features : {features}')
            features.update(time_spent_each_act.copy())
            print(f'features : {features}')
            features.update(event_code_count.copy())
            print(f'features : {features}')
            features['installation_id'] = session['installation_id'].iloc[-1] #from Andrew
            features['session_title'] = session['title'].iloc[0] 
            features['accumulated_correct_attempts'] = accumulated_correct_attempts
            features['accumulated_uncorrect_attempts'] = accumulated_uncorrect_attempts
            print(f'features : {features}')
            accumulated_correct_attempts += true_attempts 
            print(f'accumulated_correct_attempts : {accumulated_correct_attempts}')
            accumulated_uncorrect_attempts += false_attempts
            print(f'accumulated_uncorrect_attempts : {accumulated_uncorrect_attempts}')
            
            if durations == []:
                features['duration_mean'] = 0
            else:
                features['duration_mean'] = np.mean(durations)
            durations.append((session.iloc[-1, 2] - session.iloc[0, 2] ).seconds)
            features['accumulated_accuracy'] = accumulated_accuracy/counter if counter > 0 else 0
            accuracy = true_attempts/(true_attempts+false_attempts) if (true_attempts+false_attempts) != 0 else 0
            print(f'accuracy : {accuracy}')
            accumulated_accuracy += accuracy
            print(f'accumulated_accuracy : {accumulated_accuracy}')
            
            if accuracy == 0:
                features['accuracy_group'] = 0
            elif accuracy == 1:
                features['accuracy_group'] = 3
            elif accuracy == 0.5:
                features['accuracy_group'] = 2
            else:
                features['accuracy_group'] = 1
            features.update(accuracy_groups)
            print(f'features : {features}')
            accuracy_groups[features['accuracy_group']] += 1
            features['accumulated_accuracy_group'] = accumulated_accuracy_group/counter if counter > 0 else 0
            accumulated_accuracy_group += features['accuracy_group']
            features['accumulated_actions'] = accumulated_actions
            
            if test_set:
                all_assessments.append(features)
            elif true_attempts+false_attempts > 0:
                all_assessments.append(features)
                
            counter += 1
        
        n_of_event_codes = Counter(session['event_code'])
        
        for key in n_of_event_codes.keys():
            event_code_count[key] += n_of_event_codes[key]

        accumulated_actions += len(session)
        if last_activity != session_type:
            user_activities_count[session_type] += 1
            last_activitiy = session_type
    if test_set:
        return all_assessments[-1]
    return all_assessments

# %%
def LGB_bayesian(max_depth,
                 lambda_l1,
                 lambda_l2,
                 bagging_fraction,
                 bagging_freq,
                 colsample_bytree,
                 learning_rate,
                 params):
    
    params['max_depth'] = max_depth
    params['lambda_l1'] = lambda_l1
    params['lambda_l2'] = lambda_l1
    params['bagging_fraction'] = bagging_fraction
    params['bagging_freq'] = bagging_freq
    params['colsample_bytree'] = colsample_bytree
    params['learning_rate'] = learning_rate
    
    
    mt = MainTransformer()
    ft = FeatureTransformer()
    transformers = {'ft': ft}
    model = RegressorModel(model_wrapper=LGBWrapper_regr())
    model.fit(X=train, 
              y=y, 
              folds=folds, 
              params=p, 
              preprocesser=mt, 
              transformers=transformers,
# 7bd3158f    False
# fd1c8d0b    False
# 8b9047ab    False
# 6b984505    False
# 023c4bcb    False
# 6f7ffb2d    False
# 29a8065d    False
# fa338e78    False
# 4ba37cbb    False
# 9851f635    False
# da16274c    False
# db6503fa    False
# 27ff6e96    False
# eef0820e    False
# 7a6c8555    False
# 5e772257    False
# 259dbafb    False
# 21007a23    False
# db54d00d    False
# 32bc358e    False
# 212da6c0    False
# 54413e4a    False
# 8833c392    False
# bba914f4    False
# 13c26706    False
# 1bc822b4    False
# 3dc1fe35    False
# bb1489a2    False
# eeb05c1f    False
# c551fc8b    False
# 04f2cf8f    False
# bdbcd291    False
# cc477c74    False
# f822562a    False
# 67d16378    False
# c4144758    False
# b770307f    False
# ad0c2a41    False
# 9fc54908    False
# d5059e13    False
# b4674447    False
# 6f98b1a0    False
# f22c542f    False
# bcc68b76    False
# 94634a47    False
# 4443cd88    False
# ed9f779b    False
# 79af68c1    False
# 4ea9fc99    False
# 71bb1f06    False
# 51c8c346    False
# 72f3e247    False
# dc135773    False
# 721a3c54    False
# d84dc580    False
# 37b774ad    False
# 5bb1a567    False
# 2fef95e7    False
# 9c2db749    False
# 6cb3b6cd    False
# 8a390157    False
# 6a5285db    False
# 683d4057    False
# 296f8e73    False
# 4c5f57f8    False
# 6ee35159    False
# 38c0b8f3    False
# e06e3559    False
# 0ea6142a    False
# 60496d03    False
# 77d6364d    False
# 3a1f7bd9    False
# 0b80b297    False
# a9ace409    False
# d1a16d03    False
# 54b76deb    False
# 8413ba0f    False
# be98dafa    False
# 84c277b4    False
# d0fe2b52    False
# 9b55ca4a    False
# e7c41985    False
# 821a7afc    False
# b5f2a931    False
# 712548af    False
# ed9e9efa    False
# f1befae2    False
# f88f8adf    False
# c00725b2    False
# 877b8977    False
# efd5967f    False
# 321fbc89    False
# 9644f005    False
# c4d97f46    False
# be368cfe    False
# aff2929d    False
# 65efddea    False
# 349ecc0e    False
# a4b77308    False
# 4a426091    False
# f1ddb437    False
# 63291b4f     True
# ed08a824     True
# 4d54c694     True
# dce08303     True
# 74b93b04     True
# 8f2b8c82     True
# 03e38765     True
# b46e988b     True
# 80bddd3f     True
# 83c16842     True
# d4ded596     True
# d5a61500     True
# 01120f12     True
# 3d8e6b3d     True
# 56766fb1     True
# 6f1e2833     True
# 46ff1c39     True
# b957961f     True
# 6ea498d4     True
# 38509434     True
# 42c0071a     True
# d9073d30     True
# 6eecfc63     True
# 957f0606     True
# 9335712f     True
# 22c227cc     True
# 3f1abed4     True
# 04240fb1     True
# 5cd83c0a     True
# a9c55717     True
# b104e566     True
# df5ead89     True
# cae712b2     True
# 5a4a4a0b     True
# 04fbee62     True
# 9d85b31a     True
# 1a20ab68     True
# bdeb285e     True
# 350834c1     True
# 5ded4797     True
# 1014b8ac     True
# 7585b0b6     True
# 96b48ff2     True
# 16eb8609     True
# 6ce4a862     True
# 2b1e900f     True
# 7954dfae     True
# 94a457e0     True
# eb96dfca     True
# afdfc39c     True
# 04e2712b     True
# a1017fc7     True
# 2055a59a     True
# a057a188     True
# 992cd228     True
# bb318e90     True
# de0a0baf     True
# c390c9f9     True
# a48ca5b6     True
# 00ad158e     True
# 7c58f35b     True
# 98c8e99a     True
# b715f8e6     True
# e7f87673     True
# 606a3397     True
# 108634a9     True
# 35a0efa9     True
# 65439cb3     True
# 9dfc3ebb     True
# fd242541     True
# 3054e1dc     True
# 379c5ab6     True
# 5afa9cef     True
# b62c3943     True
# 930bab49     True
# 1a1c88f7     True
# 9af4d76b     True
# 869c2f40     True
# 4d2a5e4f     True
# ...
# 13e74388     True
# 9d43df2c     True
# 7c33a8a0     True
# 1435f85e     True
# 88efe794     True
# 7cf8e56c     True
# 1d019430     True
# 876f4411     True
# 80f37251     True
# a3008e81     True
# eea13247     True
# 76ed11ab     True
# 7d351303     True
# cb761f5f     True
# 79be35c1     True
# 9b5630be     True
# f0102f91     True
# 6263cc1b     True
# 50c49551     True
# 364d1a28     True
# cffa772d     True
# 94682551     True
# dcdd24ef     True
# 3ddc5f3a     True
# dcfd93b6     True
# 76375268     True
# c6dbed0c     True
# ca2b577e     True
# db5af314     True
# ad754238     True
# a62353e7     True
# 68f346e9     True
# 0f2e23b4     True
# 52f9769b     True
# 172eb0d1     True
# 38f278dc     True
# b23a1d05     True
# b6db3e5b     True
# 348f93bf     True
# b4e8876a     True
# fed331e8     True
# 453378ee     True
# c65b945a     True
# 6d2929b3     True
# bef913ca     True
# 93b35d59     True
# cccf3bec     True
# 26d524bb     True
# 446d6d10     True
# 20c21767     True
# c38ab8da     True
# ac0958c1     True
# d11f0e4d     True
# 0a0b1178     True
# 94c4ed61     True
# f7000193     True
# 905237ba     True
# a780cada     True
# 1eb38a34     True
# f80821d2     True
# 9a702a86     True
# 9f1b9354     True
# 8440941f     True
# 25016398     True
# f51a89d9     True
# 9f7d9123     True
# c87be15b     True
# 7257f1df     True
# 66c99b53     True
# 665d6f4f     True
# fce59b03     True
# 9106e333     True
# 722676d4     True
# e55aee42     True
# 75109c77     True
# ba034fca     True
# dbc95ac0     True
# 215ff509     True
# 53bfa190     True
# b6065b2e     True
# a39117b1     True
# d170a6bc     True
# 06e6a3e3     True
# e0e03cbf     True
# 7a220a9f     True
# 8d9d9212     True
# afcd81b8     True
# 07731248     True
# be17bf06     True
# 502f973f     True
# d2803718     True
# 1365c3d1     True
# f427161a     True
# 1ab42a64     True
# 66d8c823     True
# c6107333     True
# 7a7553dd     True
# fa6b6d3a     True
# a802b501     True
# 6eba02ec     True
# 2d968114     True
# 2c4f896e     True
# 45f35b9a     True
# 91957f60     True
# cb354776     True
# 2bce37dc     True
# a9c289db     True
# 69761854     True
# 57fd310d     True
# eb386d81     True
# 0d230220     True
# e19d251f     True
# 15b84ab7     True
# 16e07456     True
# c6ddded3     True
# dd598630     True
# f6715a6b     True
# a6ff7d1f     True
# 16de3583     True
# 04fa906f     True
# 915f355f     True
# 5b884149     True
# 074b4825     True
# f120e264     True
# decd4413     True
# b5dc1346     True
# 96712e61     True
# 9f7fca27     True
# 9510fa41     True
# 0e02f80d     True
# 7dcc999f     True
# 33777855     True
# 8998116a     True
# 1b4ff2dc     True
# 211c5b5b     True
# a236c419     True
# cd6d8199     True
# 0cd05f81     True
# 96debc92     True
# 4871d839     True
# 6d1d56f5     True
# 9351f85f     True
# 30689dec     True
# b817989c     True
# 37795aab     True
# 48cb2879     True
# 893fcac6     True
# 9591b4ea     True
# e610cad0     True
# c6d45de8     True
# 7e6964ce     True
# 4276a1a6     True
# f24eec67     True
# 29fdbcc5     True
# 4a58572c     True
# 9cc81584     True
# f726e95c     True
# 448ec0ef     True
# ef41c058     True
# ad9d07d6     True
# 00a53963     True
# f60c7f9e     True
# 6205eef8     True
# c32c1057     True
# 6b9e91ba     True
# f63eaa63     True
# eca4705a     True
# d07a1df9     True
# 6ea7da79     True
# cabdfee5     True
# 0c11e6a6     True
# fa2d0261     True
# 9918fb8d     True
# 7e47c64d     True
# 16218a6d     True
# fd99b7b3     True
# 50a5f350     True
# 322f7ea1     True
# 293b1825     True
# 525091ae     True
# 469855bf     True
# a1e978d1     True
# c5aad7bb     True
# ae63dc94     True
# bba2e939     True
# 942bb3ff     True
# 65185e9e     True
# fdd082f9     True
# 7a67a49d     True
# 17e0d33c     True
# 00b9d8e6     True
# 32f39539     True
# d596f097     True
# f0779cb6     True
# 6e70ec3c     True
# d34cf7b6     True
# 96b6613e     True
# 56a011cc     True
# 15dc3a59     True
# c466849a     True
# a767438e     True
# fa5ccd39     True
# 571e1cfc     True
# c6f5e38c     True
# baab1dd8     True
# e116cf1d     True
# 85ef9a48     True
# b7493efe     True
# b3bbe930     True
# 1813c8a6     True
# 846f6443     True
# 8c347aaa     True
# 7c66d28f     True
# cc233686     True
# 495b04e8     True
# 916896ed     True
# 19197e5e     True
# 8fabc729     True
# 7d8b4535     True
# 21b9f1ed     True
# 941dba20     True
# ded5df29     True
# 47858dca     True
# 758bc502     True
# 3c78ea4f     True
# d0262962     True
# 72c418b0     True
# f61e217c     True
# 50fbc866     True
# e591d6df     True
# 24b7cbeb     True
# c8c97ecd     True
# 48a48308     True
# 5c845bed     True
# fb744280     True
# 9de1a771     True
# 0925babb     True
# 0a00abf7     True
# a417c47b     True
# 9b075a0b     True
# ddc2abf5     True
# 43ccecc0     True
# 633f909b     True
# e95d2e94     True
# 6a0d6436     True
# 4696a3f5     True
# 571db614     True
# 955b4452     True
# 91455758     True
# d9dc24f8     True
# fd8ee8db     True
# b3ce385d     True
# 230b4b6e     True
# 091f80a9     True
# 4ed5a555     True
# 026e3733     True
# 4d512d60     True
# dc4c4af3     True
# e288dff8     True
# c66d0790     True
# 9d37b73d     True
# ab4544f3     True
# 4e51af2e     True
# 83c0c067     True
# 3caf9db4     True
# f611091e     True
# fe769df4     True
# 6ab702d4     True
# 50633b1a     True
# 4685f636     True
# 2d0a6638     True
# b67536dd     True
# 678a1381     True
# 08df1cd0     True
# 3470ed15     True
# 976d0410     True
# cb4d8688     True
# 2f171282     True
# c79d621e     True
# b6aefdc4     True
# 8ef357ec     True
# 888e86e2     True
# 831b7697     True
# 7b7fc9c4     True
# f0b74d78     True
# 6fd1f864     True
# 31f4e863     True
# b37e2b2d     True
# 5640400c     True
# 433d1096     True
# 4ca5b732     True
# 238c9dd2     True
# 30fc94a9     True
# 8a8a3920     True
# e389ef05     True
# 5cef8ee5     True
# 33ccb073     True
# a3d8d24c     True
# 182b7671     True
# c1486ebb     True
# 698543eb     True
# f2f6a36a     True
# 0a45d619     True
# e07b3f01     True
# 10189f14     True
# d8503f45     True
# 2a59981a     True
# b26bb86f     True
# 805e7b8f     True
# 696dcabe     True
# 0642544a     True
# b04ad194     True
# 2f252c6d     True
# c5583010     True
# 588786c9     True
# ff107709     True
# 3009466e     True
# de3108c6     True
# a183bb88     True
# 77f64809     True
# 21608806     True
# 2379e42a     True
# 549cd3e0     True
# cb8fb535     True
# b5cec608     True
# 47748670     True
# 83dc2d72     True
# 98416c8e     True
# 22ea7daf     True
# 410acfec     True
# 58171fb1     True
# 7c14c8c2     True
# fb9cae89     True
# c364f5e2     True
# 0f47f086     True
# 901ecfe3     True
# b83e5ed1     True
# a1455ee0     True
# 773e4624     True
# 280d21e1     True
# 4ae4f953     True
# 639b9091     True
# f0478d5a     True
# fcb077e7     True
# b1d58078     True
# 99e0c131     True
# 48c3d7aa     True
# fa980b6a     True
# 88ec5dcf     True
# 56956e7e     True
# 7f8d0e15     True
# ed5b26f8     True
# 315b2c14     True
# eca84be8     True
# 1da24568     True
# 9f70bc9e     True
# 447e711e     True
# 2a5c9f6b     True
# ef5cc00a     True
# 1edecf49     True
# e40e942c     True
# 6fdb3384     True
# fb9b2d13     True
# 00225f67     True
# a8daefad     True
# bd36b855     True
# 5cb2acae     True
# 81b1f135     True
# efadc70c     True
# f1147761     True
# 00cef781     True
# f97ffbc7     True
# 2d569b6d     True
# 191884de     True
# 05b198a5     True
# ef9e0144     True
# f32a1540     True
# 0fdd65f6     True
# 1e51428a     True
# 3b06140b     True
# 912ae0c2     True
# 7217511f     True
# f2841bf1     True
# 5b1bcdb9     True
# 3a53d91c     True
# a9742d69     True
# 2983a7b6     True
# b27716b8     True
# 2fcf1bec     True
# 70dc0b85     True
# 3e7f4479     True
# 17d6833a     True
# 9b490a3c     True
# 3c7a8e1e     True
# b9134e58     True
# 0d5a0603     True
# 8ffbc480     True
# 1df1f92f     True
# 01d5e1f5     True
# 08062502     True
# 50e767ea     True
# 5fa4925b     True
# b2971d2e     True
# e887cac9     True
# 5ab61e13     True
# 57d2041f     True
# e8be7dcb     True
# 65e940b5     True
# adc9de7f     True
# 344fd656     True
# a5c8a5a0     True
# 3205d05b     True
# d74e8d49     True
# 55438529     True
# b82e4aa0     True
# 703b8016     True
# dbc27a36     True
# 07c25408     True
# 7903cda1     True
# 436d5ed2     True
# 453b2148     True
# 0b105ef6     True
# fe1a1d3f     True
# a62e3878     True
# 6df65f68     True
# ad0b68a6     True
# 79b2dd87     True
# 55ef8814     True
# 8a71d796     True
# 523082ff     True
# b7a6b973     True
# afa80e96     True
# 912c157c     True
# 4065fabf     True
# 6b61f8a6     True
# a9157cbc     True
# f17c966f     True
# baef013a     True
# ec1739d2     True
# 93fbdab7     True
# 62a54ecb     True
# dcf0d150     True
# 450aaf12     True
# 4b1c8d27     True
# d76752ab     True
# dbab8519     True
# ac9eb068     True
# 705510ca     True
# 8b2e60f3     True
# ec0a422c     True
# b09b988c     True
# a3079715     True
# 17d0baa0     True
# 691d465a     True
# e3082d91     True
# a3af7515     True
# 2f607e24     True
# 191cf026     True
# 03c5998d     True
# 39f23d50     True
# 4708c14f     True
# ba4b3fa6     True
# 114a661c     True
# f2279693     True
# 7172e2d5     True
# 00279ac5     True
# b0ca8096     True
# e4701fc9     True
# e0317d16     True
# c0ef85c7     True
# 98102e27     True
# 71226edb     True
# c37c1c88     True
# 8f8bad94     True
# c7c68f00     True
# 8185df72     True
# a9627f2a     True
# 317a9387     True
# a6139da4     True
# 0b9885aa     True
# 3f1c32d7     True
# eff4be91     True
# 4ba08ec6     True
# e3d520fc     True
# 3ac7783f     True
# 8aad00ce     True
# a22c467f     True
# 8b907366     True
# a4e62501     True
# c02034f4     True
# bb0b701d     True
# ebc72f77     True
# 9652dc9c     True
# 099a3ab8     True
# f94c2ec2     True
# 4cea14e0     True
# da800ab3     True
# 246b6df7     True
# 0a386c5e     True
# d3f317c3     True
# 6042663e     True
# 7b9e1808     True
# d3f3a66d     True
# 0cb081d8     True
# 22cf747f     True
# a04ef4b7     True
# 8c32da4e     True
# 5d7c762f     True
# 3844eaca     True
# 45e6e334     True
# 9d570bf2     True
# fd019f7e     True
# b021eb99     True
# 652aba99     True
# 5ffe800b     True
# 78ffd4cf     True
# 4385cb42     True
# 48fc4ec4     True
# 5b3cb08e     True
# 8416865c     True
# 21ad5f50     True
# 16342c61     True
# dd4cc774     True
# 2a222143     True
# af46ae35     True
# d267cde7     True
# f4839ac3     True
# a836f339     True
# 5a9ee298     True
# 93f5d648     True
# 6d394bf9     True
# 28ade8fe     True
# 59a6b942     True
# 19722076     True
# 28bf9492     True
# 86a5f419     True
# 1968e1ac     True
# 6b809261     True
# e38e067a     True
# 5b0717cd     True
# fc32e3cc     True
# f97020a7     True
# 62063ae3     True
# f9254950     True
# 8c769312     True
# 65868ac8     True
# d3552f0a     True
# 726c8027     True
# d2d60c62     True
# fa283db6     True
# 0bb3bb7f     True
# 803e034b     True
# e5df3193     True
# ddd7486f     True
# c75b315b     True
# eca8c9af     True
# 1e7731ca     True
# 55ed3f08     True
# eeb1298f     True
# 52f3688e     True
# da59e22e     True
# c12b3b3c     True
# 497fd04d     True
# 1d6f86cc     True
# 0dcda606     True
# fcfefae3     True
# cdb22ca7     True
# 93d145fc     True
# 5ca747e7     True
# 69152899     True
# 4b5b02f0     True
# baa1cddb     True
# 276e06a0     True
# a7058606     True
# c7ec85d2     True
# 8b2c4a58     True
# 533d6d85     True
# 19e0a1f7     True
# 1ef92a72     True
# 3c2dfeae     True
# 49ee3af8     True
# 71b1a837     True
# 92eafa1a     True
# a67d922f     True
# c03c8bd1     True
# 88413f33     True
# e1821de7     True
# e2f772e0     True
# 2eb7fd3a     True
# 68eafb12     True
# e373f3dc     True
# 515be301     True
# fe4a63a7     True
# 7730e876     True
# 27f4aef7     True
# fb3570a9     True
# 3e622d97     True
# 97c6d02f     True
# ff7fb595     True
# 8b2b4e5d     True
# 534d42ed     True
# 1d9eefc1     True
# b5bd937c     True
# 9f2611ac     True
# d4a4c143     True
# 7f232095     True
# 9cb84bec     True
# 22cd0068     True
# 844bb0b4     True
# b272619c     True
# 7564d459     True
# 25eefcc6     True
# 38d4594d     True
# 1dbbd324     True
# b1fe8fd7     True
# 0e0a3652     True
# 30671559     True
# efeb3594     True
# 4db49f82     True
# aa619097     True
# 79b96c91     True
# 736ad54d     True
# 10629430     True
# a1a88c49     True
# 1123e9b8     True
# fca01871     True
# f18a14c9     True
# 975419a9     True
# b0f13ef1     True
# 3f2a92e1     True
# f942cfef     True
# 978fc68f     True
# 12887b75     True
# e96f8e66     True
# 798fc4dd     True
# 64240871     True
# f2b2a1dd     True
# 554e670c     True
# 69ffa407     True
# 63b0b750     True
# e98977de     True
# 81a15267     True
# 5abfefe1     True
# dfc85cd5     True
# af038715     True
# eb6ecf25     True
# ffd2871d     True
# 229905d3     True
# 4615ab1b     True
# 0bf95a69     True
# 5eda8452     True
# cd65e1a5     True
# 3ef19ad9     True
# 5a275704     True
# cd7cb46b     True
# e88d36ad     True
# aa8868b7     True
# 076b08db     True
# 39cb30b8     True
# 0ceb6116     True
# 9a6236e5     True
# 75eea838     True
# eb007cfb     True
# 465c4f74     True
# 0153c957     True
# 9ce2d074     True
# 7742c958     True
# a7d1a518     True
# 107e6f09     True
# fccdeaaf     True
# bcecdefe     True
# 0160e7c5     True
# f4ca9e73     True
# 4aaf5a7c     True
# 1098ba58     True
# d628cbf9     True
# 99b13494     True
# c5ef59a9     True
# fb43d420     True
# 6df25e1b     True
# c7fcf68c     True
# 08a47256     True
# b6abc0c2     True
# 3cc16a0f     True
# 2655d95e     True
# bcca3b6c     True
# 8d25c890     True
# 47136c04     True
# 5d9d0eee     True
# 52a67a5d     True
# 0ec92788     True
# 6d16b11a     True
# c551acf3     True
# 7c2166a6     True
# 6bb31f71     True
# cf9c9fd0     True
# a3e5afd3     True
# a7537ec4     True
# f5b609e7     True
# f77917c4     True
# 0688471f     True
# 23bec3a2     True
# 530baba5     True
# 9432d057     True
# c19ef80e     True
# dc99f858     True
# b406112e     True
# 9045746c     True
# de5194be     True
# aafddf4a     True
# 9409ddeb     True
# 593936dd     True
# 1e3ea087     True
# ea3283ad     True
# 7bd17edf     True
# 524e8ffd     True
# fc1be71e     True
# c5151af8     True
# d1cad722     True
# 3d2812a5     True
# 8182dff8     True
# db2ab253     True
# b4373bbc     True
# 7fb71751     True
# 2414a83a     True
# 26ab8f19     True
# 6272cc94     True
# d4332996     True
# ab4ae74d     True
# e83f223e     True
# 34942688     True
# 00129856     True
# 4eca440f     True
# f767c1db     True
# fb525d69     True
# d528a9ed     True
# d04adc67     True
# 89da02a3     True
# 51aefc79     True
# f5eff228     True
# bb617bfb     True
# a8744969     True
# efd6efba     True
# c49b7750     True
# 41178d5e     True
# 7f806609     True
# 29b12ea2     True
# 4ffde700     True
# ccbbf5e4     True
# 67f82f44     True
# e3836659     True
# 561e5839     True
# c7752ffe     True
# 1dfb04ab     True
# e78c1ae6     True
# 8d96d57a     True
# 02490b06     True
# 18c880c3     True
# e69ae425     True
# 43b0c813     True
# 30c18e53     True
# 9b9090eb     True
# 45e5c88e     True
# 0ca9ff42     True
# e15fdc64     True
# 494eec4b     True
# be549423     True
# 86a9b9cf     True
# e8d488e0     True
# 8ca7db4f     True
# f225addd     True
# 28ff0400     True
# 19219fcc     True
# 7bcaaa71     True
# 62b1fa70     True
# 55504fe9     True
# bf316efa     True
# b6a5d024     True
# 947a7ffb     True
# a8fcabff     True
# cc84422d     True
# 55bea02b     True
# 8c20d205     True
# 30fec3ca     True
# d15edd54     True
# ebe008dc     True
# 3e1be597     True
# e516e735     True
# ac88e56b     True
# fe9f9b60     True
# 18841c7f     True
# 1d62a6b5     True
# 6b609511     True
# 5ca281b6     True
# 2d8d1d30     True
# 3d474419     True
# abca6f9e     True
# 45341994     True
# 7b9de359     True
# 84b67881     True
# 7fc8cd95     True
# 772c4301     True
# 4d2f1f5e     True
# d54da8a4     True
# a7f3c978     True
# 73d1f78d     True
# edaa20fc     True
# 370e92d3     True
# 28c61280     True
# 3ab58ab3     True
# 4ffca9fc     True
# 21e844ce     True
# 219a2006     True
# 1ae140f6     True
# f43735f1     True
# b1068394     True
# 99f0a1bb     True
# 1c5a0788     True
# 54dbc8c7     True
# f01f1359     True
# 92f09423     True
# f38f3360     True
# 18310132     True
# b472a991     True
# d021b283     True
# 7a21aadf     True
# b246bf83     True
# afba76f6     True
# 90576156     True
# fada669c     True
# aeddf5fb     True
# a4e98645     True
# a1a044e2     True
# abaadb4c     True
# 445b1749     True
# f8c01999     True
# 2b381903     True
# 8ed93525     True
# ff00d909     True
# 9bf2c48f     True
# 8dbdeaf1     True
# 10f7bed2     True
# 97095f8d     True
# 91a1819b     True
# f2f89fa6     True
# abcdc12c     True
# a0b29bd2     True
# a899ea39     True
# 12a9a35e     True
# 7d5d107f     True
# ea40f8dc     True
# bedfb902     True
# 7b4a6f51     True
# fd97b5b2     True
# 1d10c898     True
# 8fdabccf     True
# 10ac4a88     True
# 3cdea815     True
# 2f8c8aa1     True
# 711edce2     True
# 120f5bba     True
# aa38f420     True
# b48f90a2     True
# e2382f89     True
# d9a5da1e     True
# e8d98c5d     True
# f7462cd8     True
# 62d1d90b     True
# a5b8672c     True
# 3a3c4fb5     True
# 2672b955     True
# d559bf42     True
# 858acc59     True
# 1f3b5454     True
# 0e792a70     True
# a0874395     True
# e807f0e6     True
# 3e5db1f7     True
# 36be6a97     True
# dfc6d778     True
# df56fc52     True
# 4bf4379b     True
# c297f881     True
# 117a6053     True
# a2cf1805     True
# f7281d04     True
# Name: installation_id, dtype: bool

# %%
train[train['installation_id'] == 'f7281d04']
# Out:
#           event_id      game_session                        timestamp  \
# 10945494  27253bdc  be171a624693e0ef 2019-09-03 15:33:10.437000+00:00
# 10945495  27253bdc  129c0393c1c131e3 2019-09-03 15:33:52.676000+00:00
# 10945669  7423acbc  094bd1bcd3883a31 2019-09-07 22:11:19.747000+00:00
# 10945670  27253bdc  29338b13bac6b035 2019-09-07 22:11:42.753000+00:00
#
#                                                  event_data installation_id  \
# 10945494             {"event_code": 2000, "event_count": 1}        f7281d04
# 10945495             {"event_code": 2000, "event_count": 1}        f7281d04
# 10945496             {"event_code": 2000, "event_count": 1}        f7281d04
# 10945497             {"event_code": 2000, "event_count": 1}        f7281d04
# 10945498             {"event_code": 2000, "event_count": 1}        f7281d04
# 10945499  {"version":"1.0","round":0,"event_count":1,"ga...        f7281d04
# 10945500  {"coordinates":{"x":486,"y":382,"stage_width":...        f7281d04
# 10945501  {"description":"The Claw Stars going for the g...        f7281d04
# 10945502  {"description":"The Claw Stars going for the g...        f7281d04
# 10945503  {"description":"Volume is the amount of space ...        f7281d04
# 10945504  {"description":"Volume is the amount of space ...        f7281d04
# 10945505  {"description":"The small dinosaurs will move ...        f7281d04
# 10945506  {"coordinates":{"x":277,"y":344,"stage_width":...        f7281d04
# 10945507  {"coordinates":{"x":226,"y":326,"stage_width":...        f7281d04
# 10945508  {"coordinates":{"x":129,"y":292,"stage_width":...        f7281d04
# 10945509  {"coordinates":{"x":127,"y":431,"stage_width":...        f7281d04
# 10945510  {"coordinates":{"x":60,"y":100,"stage_width":1...        f7281d04
# 10945511  {"coordinates":{"x":3,"y":132,"stage_width":10...        f7281d04
# 10945512  {"coordinates":{"x":218,"y":157,"stage_width":...        f7281d04
# 10945513  {"coordinates":{"x":149,"y":232,"stage_width":...        f7281d04
# 10945514  {"coordinates":{"x":231,"y":81,"stage_width":1...        f7281d04
# 10945515  {"coordinates":{"x":121,"y":24,"stage_width":1...        f7281d04
# 10945516  {"coordinates":{"x":366,"y":133,"stage_width":...        f7281d04
# 10945517  {"description":"The small dinosaurs will move ...        f7281d04
# 10945518  {"round":0,"event_count":20,"game_time":26075,...        f7281d04
# 10945519  {"description":"Let's warm up. Tap a dinosaur ...        f7281d04
# 10945520  {"description":"Let's warm up. Tap a dinosaur ...        f7281d04
# 10945521  {"coordinates":{"x":208,"y":81,"stage_width":1...        f7281d04
# 10945522  {"description":"Since that was a medium dinosa...        f7281d04
# 10945523  {"description":"Since that was a medium dinosa...        f7281d04
# 10945524  {"description":"Tap another dinosaur.","identi...        f7281d04
# 10945525  {"description":"Tap another dinosaur.","identi...        f7281d04
# 10945526  {"description":"Since that was a small dinosau...        f7281d04
# 10945527  {"description":"Since that was a small dinosau...        f7281d04
# 10945528  {"duration":28985,"round":0,"event_count":30,"...        f7281d04
# 10945529  {"description":"The warm-up is over, folks. Le...        f7281d04
# 10945530  {"target_water_level":3,"round":1,"event_count...        f7281d04
# 10945531  {"description":"The warm-up is over, folks. Le...        f7281d04
# 10945532  {"description":"Okay, team, we have to win fou...        f7281d04
# 10945533  {"version":"1.0","event_count":1,"game_time":0...        f7281d04
# 10945534  {"description":"Put the right sized bucket und...        f7281d04
# 10945535  {"buckets":[3,1,2],"target_bucket":0,"mode":"p...        f7281d04
# 10945536  {"description":"Put the right sized bucket und...        f7281d04
# 10945537  {"coordinates":{"x":247,"y":149,"stage_width":...        f7281d04
# 10945538  {"coordinates":{"x":294,"y":140,"stage_width":...        f7281d04
# 10945539  {"coordinates":{"x":254,"y":163,"stage_width":...        f7281d04
# 10945540  {"coordinates":{"x":513,"y":169,"stage_width":...        f7281d04
# 10945541  {"coordinates":{"x":538,"y":62,"stage_width":1...        f7281d04
# 10945542  {"buckets":[3,1,2],"correct":false,"buckets_pl...        f7281d04
# 10945543  {"description":"Place the bucket here.","ident...        f7281d04
# 10945544  {"description":"Place the bucket here.","ident...        f7281d04
# 10945545  {"description":"Place the bucket here.","ident...        f7281d04
# 10945546  {"coordinates":{"x":724,"y":211,"stage_width":...        f7281d04
# 10945547  {"description":"Place the bucket here.","ident...        f7281d04
# 10945548  {"coordinates":{"x":734,"y":205,"stage_width":...        f7281d04
# 10945549  {"coordinates":{"x":500,"y":210,"stage_width":...        f7281d04
# 10945550             {"event_code": 2000, "event_count": 1}        f7281d04
# 10945551             {"event_code": 2000, "event_count": 1}        f7281d04
# 10945552  {"version":"1.0","event_count":1,"game_time":0...        f7281d04
# 10945553  {"description":"Welcome to the garden! Which c...        f7281d04
# 10945554  {"description":"Welcome to the garden! Which c...        f7281d04
# 10945555  {"coordinates":{"x":206,"y":585,"stage_width":...        f7281d04
# 10945556  {"coordinates":{"x":209,"y":586,"stage_width":...        f7281d04
# 10945557  {"coordinates":{"x":168,"y":641,"stage_width":...        f7281d04
# 10945558  {"coordinates":{"x":170,"y":591,"stage_width":...        f7281d04
# 10945559  {"flowers":[0,0,0,0,0],"flower":0,"coordinates...        f7281d04
# 10945560  {"description":"When you're all done, tap this...        f7281d04
# 10945561  {"description":"When you're all done, tap this...        f7281d04
# 10945562  {"coordinates":{"x":877,"y":3,"stage_width":10...        f7281d04
# 10945563  {"growth":[0,3,6,8,7],"flowers":[0,3,6,8,7],"d...        f7281d04
# 10945564  {"coordinates":{"x":892,"y":745,"stage_width":...        f7281d04
# 10945565  {"flowers":[0,3,6,8,8],"flower":0,"coordinates...        f7281d04
# 10945566  {"coordinates":{"x":807,"y":4,"stage_width":10...        f7281d04
# 10945567  {"flowers":[0,3,6,8,8],"flower":0,"coordinates...        f7281d04
# 10945568  {"growth":[0,5,2,0,0],"flowers":[0,8,8,8,8],"d...        f7281d04
# 10945569  {"description":"This garden is plant-astic!","...        f7281d04
# 10945570  {"coordinates":{"x":1012,"y":724,"stage_width"...        f7281d04
# 10945571  {"growth":[1,0,0,0,0],"flowers":[1,8,8,8,8],"d...        f7281d04
# 10945572  {"description":"This garden is plant-astic!","...        f7281d04
# 10945573  {"description":"If you want to pick a flower, ...        f7281d04
# 10945574  {"growth":[3,0,0,0,0],"flowers":[4,8,8,8,8],"d...        f7281d04
# 10945575  {"description":"If you want to pick a flower, ...        f7281d04
# 10945576  {"coordinates":{"x":253,"y":169,"stage_width":...        f7281d04
# 10945577  {"growth":[2,0,0,0,0],"flowers":[6,8,8,8,8],"d...        f7281d04
# 10945578  {"flowers":[6,8,8,8,8],"flower":0,"coordinates...        f7281d04
# 10945579  {"coordinates":{"x":297,"y":116,"stage_width":...        f7281d04
# 10945580  {"growth":[1,0,0,0,0],"flowers":[7,8,8,8,8],"d...        f7281d04
# 10945581  {"flowers":[8,8,8,8,8],"flower":0,"coordinates...        f7281d04
# 10945582  {"coordinates":{"x":535,"y":312,"stage_width":...        f7281d04
# 10945583  {"flowers":[8,8,8,8,8],"flower":0,"coordinates...        f7281d04
# 10945584  {"coordinates":{"x":294,"y":299,"stage_width":...        f7281d04
# 10945585  {"version":"1.0","event_count":1,"game_time":0...        f7281d04
# 10945586  {"event_count":2,"game_time":533,"event_code":...        f7281d04
# 10945587  {"description":"Pull three mushrooms out of th...        f7281d04
# 10945588  {"coordinates":{"x":178,"y":347,"stage_width":...        f7281d04
# 10945589  {"description":"Pull three mushrooms out of th...        f7281d04
# 10945590  {"description":"To pick a mushroom, pull it ou...        f7281d04
# 10945591  {"height":4,"coordinates":{"x":283,"y":514,"st...        f7281d04
# 10945592  {"description":"To pick a mushroom, pull it ou...        f7281d04
# 10945593  {"description":"That's one!","identifier":"Dot...        f7281d04
# 10945594  {"description":"That's one!","identifier":"Dot...        f7281d04
# 10945595  {"coordinates":{"x":524,"y":108,"stage_width":...        f7281d04
# 10945596  {"version":"1.0","event_count":1,"game_time":0...        f7281d04
# 10945597  {"event_count":2,"game_time":715,"event_code":...        f7281d04
# 10945598  {"description":"Pull three mushrooms out of th...        f7281d04
# 10945599  {"description":"Pull three mushrooms out of th...        f7281d04
# 10945600  {"description":"To pick a mushroom, pull it ou...        f7281d04
# 10945601  {"description":"To pick a mushroom, pull it ou...        f7281d04
# 10945602  {"version":"1.0","event_count":1,"game_time":0...        f7281d04
# 10945603  {"event_count":2,"game_time":543,"event_code":...        f7281d04
# 10945604  {"description":"Pull three mushrooms out of th...        f7281d04
# 10945605  {"description":"Pull three mushrooms out of th...        f7281d04
# 10945606  {"description":"To pick a mushroom, pull it ou...        f7281d04
# 10945607  {"description":"To pick a mushroom, pull it ou...        f7281d04
# 10945608  {"version":"1","round":0,"event_count":1,"game...        f7281d04
# 10945609  {"coordinates":{"x":827,"y":315,"stage_width":...        f7281d04
# 10945610  {"coordinates":{"x":11,"y":350,"stage_width":1...        f7281d04
# 10945611  {"coordinates":{"x":859,"y":394,"stage_width":...        f7281d04
# 10945612  {"round":0,"event_count":5,"game_time":14452,"...        f7281d04
# 10945613  {"description":"First, click the space where y...        f7281d04
# 10945614  {"description":"First, click the space where y...        f7281d04
# 10945615  {"description":"That's it!  The further back y...        f7281d04
# 10945616  {"coordinates":{"x":86,"y":295,"stage_width":1...        f7281d04
# 10945617  {"coordinates":{"x":95,"y":283,"stage_width":1...        f7281d04
# 10945618  {"coordinates":{"x":105,"y":305,"stage_width":...        f7281d04
# 10945619  {"description":"That's it!  The further back y...        f7281d04
# 10945620  {"description":"Now, tap the green \"go\" butt...        f7281d04
# 10945621  {"duration":12905,"tutorial_step":3,"round":0,...        f7281d04
# 10945622  {"description":"Now, tap the green \"go\" butt...        f7281d04
# 10945623  {"description":"The other team will fly first....        f7281d04
# 10945624  {"target_distances":[4,5,6,7,8,9,10],"round_pr...        f7281d04
# 10945625  {"coordinates":{"x":163,"y":270,"stage_width":...        f7281d04
# 10945626  {"coordinates":{"x":185,"y":249,"stage_width":...        f7281d04
# 10945627  {"description":"The other team will fly first....        f7281d04
# 10945628  {"description":"I want you to fly farther than...        f7281d04
# 10945629  {"description":"I want you to fly farther than...        f7281d04
# 10945630  {"description":"I want you to fly farther than...        f7281d04
# 10945631  {"distance":9,"dinosaur":"tiny","target_distan...        f7281d04
# 10945632  {"description":"I want you to fly farther than...        f7281d04
# 10945633  {"description":"You moved your dinosaur Nine s...        f7281d04
# 10945634  {"distance":10,"dinosaur":"tiny","target_dista...        f7281d04
# 10945635  {"description":"You moved your dinosaur Nine s...        f7281d04
# 10945636  {"description":"You moved your dinosaur Ten sp...        f7281d04
# 10945637  {"coordinates":{"x":676,"y":237,"stage_width":...        f7281d04
# 10945638  {"description":"You moved your dinosaur Ten sp...        f7281d04
# 10945639  {"distance":10,"target_distances":[4,5,6,7,8,9...        f7281d04
# 10945640  {"description":"You did it!","identifier":"You...        f7281d04
# 10945641  {"description":"You did it!","identifier":"You...        f7281d04
# 10945642  {"duration":44747,"misses":0,"round":1,"event_...        f7281d04
# 10945643  {"description":"There goes the other team.","i...        f7281d04
# 10945644  {"target_distances":[3,4,5],"round_prompt":"Ob...        f7281d04
# 10945645  {"description":"There goes the other team.","i...        f7281d04
# 10945646  {"description":"I want you to land as close as...        f7281d04
# 10945647  {"coordinates":{"x":70,"y":243,"stage_width":1...        f7281d04
# 10945648  {"coordinates":{"x":68,"y":258,"stage_width":1...        f7281d04
# 10945649  {"description":"I want you to land as close as...        f7281d04
# 10945650  {"distance":8,"dinosaur":"don","target_distanc...        f7281d04
# 10945651  {"description":"You moved your dinosaur Eight ...        f7281d04
# 10945652  {"coordinates":{"x":58,"y":261,"stage_width":1...        f7281d04
# 10945653  {"distance":10,"dinosaur":"don","target_distan...        f7281d04
# 10945654  {"description":"You moved your dinosaur Eight ...        f7281d04
# 10945655  {"description":"You moved your dinosaur Ten sp...        f7281d04
# 10945656  {"coordinates":{"x":81,"y":255,"stage_width":1...        f7281d04
# 10945657  {"description":"You moved your dinosaur Ten sp...        f7281d04
# 10945658  {"distance":10,"target_distances":[3,4,5],"cor...        f7281d04
# 10945659  {"description":"So close! But you flew too far...        f7281d04
# 10945660  {"description":"So close! But you flew too far...        f7281d04
# 10945661  {"description":"I want you to land as close as...        f7281d04
# 10945662  {"description":"I want you to land as close as...        f7281d04
# 10945663  {"coordinates":{"x":66,"y":278,"stage_width":1...        f7281d04
# 10945664  {"distance":9,"dinosaur":"don","target_distanc...        f7281d04
# 10945665  {"description":"You moved your dinosaur Nine s...        f7281d04
# 10945666  {"coordinates":{"x":475,"y":227,"stage_width":...        f7281d04
# 10945667  {"description":"You moved your dinosaur Nine s...        f7281d04
# 10945668  {"distance":9,"target_distances":[3,4,5],"corr...        f7281d04
